# %%
#time subprocess.call('ncks -v total_alkalinity SalishSea_1ts_20171026_20171026_ptrc_T.nc TA_1h.nc', shell=True,cwd=resdir)\n"

from __future__ import print_function
from numpy import *
from scipy import *
import netCDF4 as nc
import numpy as np
import scipy as sp
import seawater

import datetime as dt
import sys
import subprocess
# import river_201702 as rv
""
from salishsea_tools import (
    nc_tools,
    viz_tools, 
    geo_tools,
    tidetools
)
import matplotlib.pyplot as plt
#matplotlib.use('Agg')
import matplotlib.patches as patches
plt.style.use('seaborn-whitegrid')
import netCDF4 as nc

import cmocean as cm
import glob
import sys
sys.path.append('/data/tjarniko/mocsy')
sys.path.append('/data/tjarniko/MEOPAR/at3/notebooks/carbon_dev/CCCmaDEV/CCCma_src')
sys.path.append('/data/tjarniko/MEOPAR/tools/SalishSeaTools/salishsea_tools/')
import mocsy
import CCCma
import CCCma_stations as cs
from matplotlib import reload
import arrow
import gsw

# %matplotlib inline
# Out:
# /home/tjarniko/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1357: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
#%time subprocess.call('ncks -v dissolved_inorganic_carbon SalishSea_1ts_20171026_20171026_ptrc_T.nc DIC_1h.nc', shell=True,cwd=resdir)
#%time subprocess.call('ncks -v total_alkalinity SalishSea_1ts_20171026_20171026_ptrc_T.nc TA_1h.nc', shell=True,cwd=resdir)

# %%
#/data/tjarniko/results/BR_1st_2015/ncs/SKOG_1d_20151028_20151126_ptrc_T_20151126-20151126.nc
resdir = '/data/tjarniko/results/BR_1st_2015/ncs/'

time subprocess.call(ncks -4 -L4 -O SKOG_1d_20151028_20151126_ptrc_T_20151126-20151126.nc SKOG_1d_20151028_20151126_ptrc_T_20151126-20151126.nc, shell=True,cwd=resdir)
#ncks -4 -L -O

# %%
# %time subprocess.call(ncks -4 -L -0 SKOG_1d_20151028_20151126_ptrc_T_20151126-20151126.nc SKOG_1d_20151028_20151126_ptrc_T_20151126-20151126.nc)

# %%
import glob
import subprocess

for fn in glob.iglob('/data/tjarniko/results/BR_1st_2015/ncs/*.nc'):
    print(fn)
    output_fn = fn
    
    subprocess.run(['ncks', '-4', '-L4', '-O', fn, output_fn])
    
#     output = subprocess.call(['ncks', '-4', '-L', '-0', '-o', fn, output_fn], shell=True)
# #     print(output)
# Out:
# /data/tjarniko/results/BR_1st_2015/ncs/SKOG_1d_20150630_20150729_grid_V_20150722-20150722.nc
# /data/tjarniko/results/BR_1st_2015/ncs/SKOG_1d_20150302_20150331_dian_W_20150323-20150323.nc
# /data/tjarniko/results/BR_1st_2015/ncs/SKOG_1d_20150302_20150331_grid_V_20150319-20150319.nc
# /data/tjarniko/results/BR_1st_2015/ncs/SKOG_1d_20150531_20150629_dian_W_20150609-20150609.nc
# /data/tjarniko/results/BR_1st_2015/ncs/SKOG_1d_20151028_20151126_grid_W_20151109-20151109.nc
# /data/tjarniko/results/BR_1st_2015/ncs/SKOG_1d_20150131_20150301_dian_W_20150218-20150218.nc
# /data/tjarniko/results/BR_1st_2015/ncs/SKOG_1d_20150302_20150331_carp_T_20150323-20150323.nc
# /data/tjarniko/results/BR_1st_2015/ncs/SKOG_1d_20150131_20150301_grid_T_20150219-20150219.nc
# /data/tjarniko/results/BR_1st_2015/ncs/SKOG_1d_20150928_20151027_grid_U_20150928-20150928.nc
# /data/tjarniko/results/BR_1st_2015/ncs/SKOG_1d_20150501_20150530_grid_W_20150517-20150517.nc
# ...

# %%
fn = 'SKOG_1d_20151028_20151126_ptrc_T_20151126-20151126.nc'
output_fn = 'SKOG_1d_20151028_20151126_ptrc_T_20151126-20151126.nc'
subprocess.call(['ncks', '-4', '-L', '-0', fn, output_fn])

# %%
import shlex

subprocess.run(shlex.split(f"ncks -4 -L4 -O {fn} {output_fn}"))
