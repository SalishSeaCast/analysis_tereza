# %%
# %reset
# from numpy import *
# from scipy import *

# from scipy import stats 
# from scipy import interpolate


import netCDF4 as nc
import numpy as np
from scipy.optimize import curve_fit
from numpy import exp, linspace, random
# import scipy as sp
import cmocean
import glob
import seawater
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import cmocean as cm


import sys
sys.path.append('/data/tjarniko/mocsy')
sys.path.append('/data/tjarniko/MEOPAR/at3/notebooks/carbon_dev/CCCmaDEV/CCCma_src')
sys.path.append('/data/tjarniko/MEOPAR/at3/notebooks/carbon_dev/VIZ/')

import VIZ_plots as VP

from salishsea_tools import (
    nc_tools,
    viz_tools,
    geo_tools,
    tidetools
)

import warnings
warnings.filterwarnings('ignore')

help(VP)
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
# Help on module VIZ_plots:
#
# NAME
#     VIZ_plots
#
# FUNCTIONS
#     ONC_animator(plotdat, tstart, tend, v_min, v_max, stepsize, tit1, tit2, figtit, dirstr, tcmap, clabel, indexer)
#
#     animate_surf(hrly_dat, tit, v_min, v_max, t_cmap)
#         TESTED
#
#     nice_CN_plot(tit1, tit2, plotdat, physdat, t, v_min, v_max, tcmap, clabel)
#         NOT TESTED
#
#     one_panel_plot(surfdat_1, tit1, t_cmap, xsize, ysize, v_min1, v_max1, cl1, bigtit)
#         TESTED
#
#     phpco2om_plot(surfdat_1, surfdat_2, surfdat_3, tit1, tit2, tit3, t_cmap1, t_cmap2, t_cmap3, xsize, ysize, v_min1, v_max1, v_min2, v_max2, v_min3, v_max3, cl1, cl2, cl3, bigtit, dirstr, ind)
#         TESTED
#
#     thalweg_animator(plotdat, tstart, tend, vmin, vmax, stepsize, tit, tit2, figtit, dirstr, indexer, t_cmap, clabel)
#         TESTED
#
# ...

# %%
cedarrefdir = '/data/tjarniko/results/RFPARTY/rfncs/'
grahamtestdir = '/data/tjarniko/results/n7DET/'
ncname = 'SKOG_1d_20180201_20180202_carp_T_20180201-20180201.nc'
ncname2 = 'SKOG_1d_20180201_20180215_carp_T_20180201-20180201.nc'

cedar_ref = nc.Dataset(cedarrefdir+ncname2)
graham_test = nc.Dataset(grahamtestdir+ncname)

# %%
g_DIC = graham_test.variables['dissolved_inorganic_carbon']
c_DIC = cedar_ref.variables['dissolved_inorganic_carbon']

# %%
VP.two_panel_plot(g_DIC[0,0,:,:],c_DIC[0,0,:,:],'graham - test', 'cedar -ref',cm.cm.deep_r,10,10,1600,2300,1600,2300,'dic','dic','comparison - surface values')

# %%
VP.two_panel_plot(g_DIC[0,0,:,:],g_DIC[0,0,:,:]-c_DIC[0,0,:,:],'graham - test', 'cedar-graham diff',\
                  cm.cm.deep_r,10,10,1600,2300,-0.1,0.1,'dic','dic','comparison - surface values')
