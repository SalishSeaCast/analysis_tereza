# %% [markdown]
# ## MF5

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Mythical code button"></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Mythical code button"></form>

# %%
import arrow
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
#plt.style.use('classic')
from matplotlib.patches import Rectangle
import pickle
from cmocean import cm
import warnings
import netCDF4 as nc
import sys
sys.path.append('../pyscripts/bylayer_extract/')
import extract_bylayer_mean_BOXMASK as ebmBOX 
from importlib import reload
from salishsea_tools import viz_tools

import sys
sys.path.append('/data/tjarniko/mocsy')
import mocsy

# %matplotlib inline
warnings.simplefilter('ignore')

# plt.rcParams.update({'font.size': 13,
#                      'xtick.labelsize' : 13,
#                      'ytick.labelsize' : 13})

# %% [markdown]
# ## extract the seasonal averages for DIC, TA, temp, sal

# %%
import glob

tvar ='dissolved_inorganic_carbon'
# summer and winter mean 

#winter1 - december

start ='2015-12-01'
end ='2015-12-31'

start_run = arrow.get(start)
end_run = arrow.get(end)

arrow_array1 = []

for r in arrow.Arrow.span_range('day', start_run, end_run):
    arrow_array1.append(r)
dayslen = len(arrow_array1)

BR_winter1 = np.zeros([dayslen,40,898,398])

for i in range(0,dayslen):

    tdate = arrow_array1[i][0]
    ymd = tdate.format('YYYYMMDD')

    if i%20 == 0:
        print(ymd)
    tstr = glob.glob('//data/tjarniko/results/BASERUN_EXP/PI9/ncs/SKOG*carp*'+ymd+'*.nc')
    tnc = tstr[0]
    tn = nc.Dataset(tnc)
    t_dic = tn[tvar][0,:,:,:]
    BR_winter1[i,:,:,:] = t_dic

#winter 2 is january-february
start ='2015-01-01'
end ='2015-02-28'

start_run = arrow.get(start)
end_run = arrow.get(end)
arrow_array2 = []

for r in arrow.Arrow.span_range('day', start_run, end_run):
    arrow_array2.append(r)
dayslen = len(arrow_array2)

BR_winter2 = np.zeros([dayslen,40,898,398])

for i in range(0,dayslen):

    tdate = arrow_array2[i][0]
    ymd = tdate.format('YYYYMMDD')

    if i%20 == 0:
        print(ymd)
    tstr = glob.glob('//data/tjarniko/results/BASERUN_EXP/PI9/ncs/SKOG*carp*'+ymd+'*.nc')
    tnc = tstr[0]
    tn = nc.Dataset(tnc)
    t_dic = tn['dissolved_inorganic_carbon'][0,:,:,:]
    BR_winter2[i,:,:,:] = t_dic


BR_winter = np.concatenate((BR_winter1,BR_winter2),axis=0)
print(np.shape(BR_winter))
BR_winter_mean = np.nanmean(BR_winter,axis=0)
pickle.dump(BR_winter_mean, open("./pkls/PI9_DIC_winter_mean.pkl", 'wb'))

start ='2015-06-01'
end ='2015-08-31'

start_run = arrow.get(start)
end_run = arrow.get(end)

arrow_array1 = []

for r in arrow.Arrow.span_range('day', start_run, end_run):
    arrow_array1.append(r)
dayslen = len(arrow_array1)

BR_oma_summer1 = np.zeros([dayslen,40,898,398])

for i in range(0,dayslen):

    tdate = arrow_array1[i][0]
    ymd = tdate.format('YYYYMMDD')

    if i%10 == 0:
        print(ymd)
    tstr = glob.glob('//data/tjarniko/results/BASERUN_EXP/PI9/ncs/SKOG*carp*'+ymd+'*.nc')
    tnc = tstr[0]
    tn = nc.Dataset(tnc)
    t_dic = tn[tvar][0,:,:,:]
    BR_oma_summer1[i,:,:,:] = t_dic


print(np.shape(BR_oma_summer1))
BR_oma_summer_mean = np.nanmean(BR_oma_summer1,axis=0)
pickle.dump(BR_oma_summer_mean, open("./pkls/PI9_DIC_summer_mean.pkl", 'wb'))
# Out:
# 20151201
# 20151221
# 20150101
# 20150121
# 20150210
# (90, 40, 898, 398)
# 20150601
# 20150611
# 20150621
# 20150701
# 20150711
# 20150721
# 20150731
# 20150810
# 20150820
# 20150830
# (92, 40, 898, 398)

# %%
tvar ='total_alkalinity'
# summer and winter mean 

#winter1 - december

start ='2015-12-01'
end ='2015-12-31'

start_run = arrow.get(start)
end_run = arrow.get(end)

arrow_array1 = []

for r in arrow.Arrow.span_range('day', start_run, end_run):
    arrow_array1.append(r)
dayslen = len(arrow_array1)

BR_winter1 = np.zeros([dayslen,40,898,398])

for i in range(0,dayslen):

    tdate = arrow_array1[i][0]
    ymd = tdate.format('YYYYMMDD')

    if i%20 == 0:
        print(ymd)
    tstr = glob.glob('//data/tjarniko/results/BASERUN_EXP/PI9/ncs/SKOG*carp*'+ymd+'*.nc')
    tnc = tstr[0]
    tn = nc.Dataset(tnc)
    t_TA = tn[tvar][0,:,:,:]
    BR_winter1[i,:,:,:] = t_TA

#winter 2 is january-february
start ='2015-01-01'
end ='2015-02-28'

start_run = arrow.get(start)
end_run = arrow.get(end)
arrow_array2 = []

for r in arrow.Arrow.span_range('day', start_run, end_run):
    arrow_array2.append(r)
dayslen = len(arrow_array2)

BR_winter2 = np.zeros([dayslen,40,898,398])

for i in range(0,dayslen):

    tdate = arrow_array2[i][0]
    ymd = tdate.format('YYYYMMDD')

    if i%20 == 0:
        print(ymd)
    tstr = glob.glob('//data/tjarniko/results/BASERUN_EXP/PI9/ncs/SKOG*carp*'+ymd+'*.nc')
    tnc = tstr[0]
    tn = nc.Dataset(tnc)
    t_TA = tn[tvar][0,:,:,:]
    BR_winter2[i,:,:,:] = t_TA


BR_winter = np.concatenate((BR_winter1,BR_winter2),axis=0)
print(np.shape(BR_winter))
BR_winter_mean = np.nanmean(BR_winter,axis=0)
pickle.dump(BR_winter_mean, open("./pkls/PI9_TA_winter_mean.pkl", 'wb'))

start ='2015-06-01'
end ='2015-08-31'

start_run = arrow.get(start)
end_run = arrow.get(end)

arrow_array1 = []

for r in arrow.Arrow.span_range('day', start_run, end_run):
    arrow_array1.append(r)
dayslen = len(arrow_array1)

BR_oma_summer1 = np.zeros([dayslen,40,898,398])

for i in range(0,dayslen):

    tdate = arrow_array1[i][0]
    ymd = tdate.format('YYYYMMDD')

    if i%10 == 0:
        print(ymd)
    tstr = glob.glob('//data/tjarniko/results/BASERUN_EXP/PI9/ncs/SKOG*carp*'+ymd+'*.nc')
    tnc = tstr[0]
    tn = nc.Dataset(tnc)
    t_TA = tn[tvar][0,:,:,:]
    BR_oma_summer1[i,:,:,:] = t_TA
tvar ='total_alkalinity'
# summer and winter mean 

#winter1 - december

start ='2015-12-01'
end ='2015-12-31'

start_run = arrow.get(start)
end_run = arrow.get(end)

arrow_array1 = []

for r in arrow.Arrow.span_range('day', start_run, end_run):
    arrow_array1.append(r)
dayslen = len(arrow_array1)

BR_winter1 = np.zeros([dayslen,40,898,398])

for i in range(0,dayslen):

    tdate = arrow_array1[i][0]
    ymd = tdate.format('YYYYMMDD')

    if i%20 == 0:
        print(ymd)
    tstr = glob.glob('//data/tjarniko/results/BASERUN_EXP/PI9/ncs/SKOG*carp*'+ymd+'*.nc')
    tnc = tstr[0]
    tn = nc.Dataset(tnc)
    t_TA = tn[tvar][0,:,:,:]
    BR_winter1[i,:,:,:] = t_TA

#winter 2 is january-february
start ='2015-01-01'
end ='2015-02-28'

start_run = arrow.get(start)
end_run = arrow.get(end)
arrow_array2 = []

for r in arrow.Arrow.span_range('day', start_run, end_run):
    arrow_array2.append(r)
dayslen = len(arrow_array2)

BR_winter2 = np.zeros([dayslen,40,898,398])

for i in range(0,dayslen):

    tdate = arrow_array2[i][0]
    ymd = tdate.format('YYYYMMDD')

    if i%20 == 0:
        print(ymd)
    tstr = glob.glob('//data/tjarniko/results/BASERUN_EXP/PI9/ncs/SKOG*carp*'+ymd+'*.nc')
    tnc = tstr[0]
    tn = nc.Dataset(tnc)
    t_TA = tn[tvar][0,:,:,:]
    BR_winter2[i,:,:,:] = t_TA


BR_winter = np.concatenate((BR_winter1,BR_winter2),axis=0)
print(np.shape(BR_winter))
BR_winter_mean = np.nanmean(BR_winter,axis=0)
pickle.dump(BR_winter_mean, open("./pkls/PI9_TA_winter_mean.pkl", 'wb'))

start ='2015-06-01'
end ='2015-08-31'

start_run = arrow.get(start)
end_run = arrow.get(end)

arrow_array1 = []

for r in arrow.Arrow.span_range('day', start_run, end_run):
    arrow_array1.append(r)
dayslen = len(arrow_array1)

BR_oma_summer1 = np.zeros([dayslen,40,898,398])

for i in range(0,dayslen):

    tdate = arrow_array1[i][0]
    ymd = tdate.format('YYYYMMDD')

    if i%10 == 0:
        print(ymd)
    tstr = glob.glob('//data/tjarniko/results/BASERUN_EXP/PI9/ncs/SKOG*carp*'+ymd+'*.nc')
    tnc = tstr[0]
    tn = nc.Dataset(tnc)
    t_TA = tn[tvar][0,:,:,:]
    BR_oma_summer1[i,:,:,:] = t_TA


print(np.shape(BR_oma_summer1))
BR_oma_summer_mean = np.nanmean(BR_oma_summer1,axis=0)
pickle.dump(BR_oma_summer_mean, open("./pkls/PI9_TA_summer_mean.pkl", 'wb'))

print(np.shape(BR_oma_summer1))
BR_oma_summer_mean = np.nanmean(BR_oma_summer1,axis=0)
pickle.dump(BR_oma_summer_mean, open("./pkls/PI9_TA_summer_mean.pkl", 'wb'))
# Out:
# 20151201
# 20151221
# 20150101
# 20150121
# 20150210
# (90, 40, 898, 398)
# 20150601
# 20150611
# 20150621
# 20150701
# 20150711
# 20150721
# 20150731
# 20150810
# 20150820
# 20150830
# 20151201
# 20151221
# 20150101
# 20150121
# 20150210
# (90, 40, 898, 398)
# 20150601
# 20150611
# 20150621
# 20150701
# 20150711
# 20150721
# 20150731
# 20150810
# 20150820
# 20150830
# (92, 40, 898, 398)
# (92, 40, 898, 398)

# %%
tvar ='vosaline'
# summer and winter mean 

#winter1 - december

start ='2015-12-01'
end ='2015-12-31'

start_run = arrow.get(start)
end_run = arrow.get(end)

arrow_array1 = []

for r in arrow.Arrow.span_range('day', start_run, end_run):
    arrow_array1.append(r)
dayslen = len(arrow_array1)

BR_winter1 = np.zeros([dayslen,40,898,398])

for i in range(0,dayslen):

    tdate = arrow_array1[i][0]
    ymd = tdate.format('YYYYMMDD')

    if i%20 == 0:
        print(ymd)
    tstr = glob.glob('//data/tjarniko/results/BASERUN_EXP/PI9/ncs/SKOG*grid_T*'+ymd+'*.nc')
    tnc = tstr[0]
    tn = nc.Dataset(tnc)
    t_TA = tn[tvar][0,:,:,:]
    BR_winter1[i,:,:,:] = t_TA

#winter 2 is january-february
start ='2015-01-01'
end ='2015-02-28'

start_run = arrow.get(start)
end_run = arrow.get(end)
arrow_array2 = []

for r in arrow.Arrow.span_range('day', start_run, end_run):
    arrow_array2.append(r)
dayslen = len(arrow_array2)

BR_winter2 = np.zeros([dayslen,40,898,398])

for i in range(0,dayslen):

    tdate = arrow_array2[i][0]
    ymd = tdate.format('YYYYMMDD')

    if i%20 == 0:
        print(ymd)
    tstr = glob.glob('//data/tjarniko/results/BASERUN_EXP/PI9/ncs/SKOG*grid_T*'+ymd+'*.nc')
    tnc = tstr[0]
    tn = nc.Dataset(tnc)
    t_TA = tn[tvar][0,:,:,:]
    BR_winter2[i,:,:,:] = t_TA


BR_winter = np.concatenate((BR_winter1,BR_winter2),axis=0)
print(np.shape(BR_winter))
BR_winter_mean = np.nanmean(BR_winter,axis=0)
pickle.dump(BR_winter_mean, open("./pkls/PI9_sal_winter_mean.pkl", 'wb'))

start ='2015-06-01'
end ='2015-08-31'

start_run = arrow.get(start)
end_run = arrow.get(end)

arrow_array1 = []

for r in arrow.Arrow.span_range('day', start_run, end_run):
    arrow_array1.append(r)
dayslen = len(arrow_array1)

BR_oma_summer1 = np.zeros([dayslen,40,898,398])

for i in range(0,dayslen):

    tdate = arrow_array1[i][0]
    ymd = tdate.format('YYYYMMDD')

    if i%10 == 0:
        print(ymd)
    tstr = glob.glob('//data/tjarniko/results/BASERUN_EXP/PI9/ncs/SKOG*grid_T*'+ymd+'*.nc')
    tnc = tstr[0]
    tn = nc.Dataset(tnc)
    t_TA = tn[tvar][0,:,:,:]
    BR_oma_summer1[i,:,:,:] = t_TA


print(np.shape(BR_oma_summer1))
BR_oma_summer_mean = np.nanmean(BR_oma_summer1,axis=0)
pickle.dump(BR_oma_summer_mean, open("../pkls/PI9_sal_summer_mean.pkl", 'wb'))
# Out:
# 20151201
# 20151221
# 20150101
# 20150121
# 20150210
# (90, 40, 898, 398)
# 20150601
# 20150611
# 20150621
# 20150701
# 20150711
# 20150721
# 20150731
# 20150810
# 20150820
# 20150830
# (92, 40, 898, 398)

# %%
tvar ='votemper'
# summer and winter mean 

#winter1 - december

start ='2015-12-01'
end ='2015-12-31'

start_run = arrow.get(start)
end_run = arrow.get(end)

arrow_array1 = []

for r in arrow.Arrow.span_range('day', start_run, end_run):
    arrow_array1.append(r)
dayslen = len(arrow_array1)

BR_winter1 = np.zeros([dayslen,40,898,398])

for i in range(0,dayslen):

    tdate = arrow_array1[i][0]
    ymd = tdate.format('YYYYMMDD')

    if i%20 == 0:
        print(ymd)
    tstr = glob.glob('//data/tjarniko/results/BASERUN_EXP/PI9/ncs/SKOG*grid_T*'+ymd+'*.nc')
    tnc = tstr[0]
    tn = nc.Dataset(tnc)
    t_TA = tn[tvar][0,:,:,:]
    BR_winter1[i,:,:,:] = t_TA

#winter 2 is january-february
start ='2015-01-01'
end ='2015-02-28'

start_run = arrow.get(start)
end_run = arrow.get(end)
arrow_array2 = []

for r in arrow.Arrow.span_range('day', start_run, end_run):
    arrow_array2.append(r)
dayslen = len(arrow_array2)

BR_winter2 = np.zeros([dayslen,40,898,398])

for i in range(0,dayslen):

    tdate = arrow_array2[i][0]
    ymd = tdate.format('YYYYMMDD')

    if i%20 == 0:
        print(ymd)
    tstr = glob.glob('//data/tjarniko/results/BASERUN_EXP/PI9/ncs/SKOG*grid_T*'+ymd+'*.nc')
    tnc = tstr[0]
    tn = nc.Dataset(tnc)
    t_TA = tn[tvar][0,:,:,:]
    BR_winter2[i,:,:,:] = t_TA


BR_winter = np.concatenate((BR_winter1,BR_winter2),axis=0)
print(np.shape(BR_winter))
BR_winter_mean = np.nanmean(BR_winter,axis=0)
pickle.dump(BR_winter_mean, open("./pkls/PI9_temp_winter_mean.pkl", 'wb'))

start ='2015-06-01'
end ='2015-08-31'

start_run = arrow.get(start)
end_run = arrow.get(end)

arrow_array1 = []

for r in arrow.Arrow.span_range('day', start_run, end_run):
    arrow_array1.append(r)
dayslen = len(arrow_array1)

BR_oma_summer1 = np.zeros([dayslen,40,898,398])

for i in range(0,dayslen):

    tdate = arrow_array1[i][0]
    ymd = tdate.format('YYYYMMDD')

    if i%10 == 0:
        print(ymd)
    tstr = glob.glob('//data/tjarniko/results/BASERUN_EXP/PI9/ncs/SKOG*grid_T*'+ymd+'*.nc')
    tnc = tstr[0]
    tn = nc.Dataset(tnc)
    t_TA = tn[tvar][0,:,:,:]
    BR_oma_summer1[i,:,:,:] = t_TA


print(np.shape(BR_oma_summer1))
BR_oma_summer_mean = np.nanmean(BR_oma_summer1,axis=0)
pickle.dump(BR_oma_summer_mean, open("./pkls/PI9_temp_summer_mean.pkl", 'wb'))
# Out:
# 20151201
# 20151221
# 20150101
# 20150121
# 20150210
# (90, 40, 898, 398)
# 20150601
# 20150611
# 20150621
# 20150701
# 20150711
# 20150721
# 20150731
# 20150810
# 20150820
# 20150830
# (92, 40, 898, 398)
