# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from mpl_toolkits.basemap import Basemap
from scipy.io import loadmat
import cmocean
import warnings
import arrow
from salishsea_tools import viz_tools, places
import netCDF4 as nc
import pickle
from salishsea_tools import visualisations as vis
#import LambertConformalTicks as lct

# %matplotlib inline
plt.rcParams['font.size'] = 11
warnings.simplefilter('ignore')

# %% [markdown]
# # code for extracting OmC averages -summer
#
# #### - BR3 summer - jun 20 - sept 22 and jun 1-aug31
# #### - PI3rr summer - jun 20 - sept 22 and jun 1-aug31
#
# #summer is june 20th to sept 22
# #winter is dec 21 to thursday march 19

# %%
# # BR3

# start ='2015-06-20'
# end ='2015-09-22'

# start_run = arrow.get(start)
# end_run = arrow.get(end)

# arrow_array = []

# for r in arrow.Arrow.span_range('day', start_run, end_run):
#     arrow_array.append(r)

# dayslen = len(arrow_array)

# BR_OmC_summer = np.zeros([dayslen,40,898,398])

# for i in range(0,dayslen):

#     tdate = arrow_array[i][0]
#     ymd = tdate.format('YYYYMMDD')

#     if i%10 == 0:
#         print(ymd)
#     t_pco2 = nc.Dataset('//data/tjarniko/results/BASERUN_EXP/Oma_calc/BR3_OmA_plus_'+ymd+'.nc')
#     t_OmC = t_pco2['model_output']['OmC'][:,:,:]
#     BR_OmC_summer[i,:,:,:] = t_OmC

# BR_OmC_summer_mean = np.nanmean(BR_OmC_summer,axis=0)
# pickle.dump(BR_OmC_summer_mean, open("./pkls/BR3_OmC_SUMMERmean_20jun_22sep.pkl", 'wb'))
# print(np.shape(BR_OmC_summer_mean))

# #BR3
# start ='2015-06-01'
# end ='2015-08-31'

# start_run = arrow.get(start)
# end_run = arrow.get(end)

# arrow_array = []

# for r in arrow.Arrow.span_range('day', start_run, end_run):
#     arrow_array.append(r)

# dayslen = len(arrow_array)

# BR_OmC_summer = np.zeros([dayslen,40,898,398])

# for i in range(0,dayslen):

#     tdate = arrow_array[i][0]
#     ymd = tdate.format('YYYYMMDD')

#     if i%10 == 0:
#         print(ymd)
#     t_pco2 = nc.Dataset('//data/tjarniko/results/BASERUN_EXP/Oma_calc/BR3_OmA_plus_'+ymd+'.nc')
#     t_OmC = t_pco2['model_output']['OmC'][:,:,:]
#     BR_OmC_summer[i,:,:,:] = t_OmC

# BR_OmC_summer_mean = np.nanmean(BR_OmC_summer,axis=0)
# pickle.dump(BR_OmC_summer_mean, open("./pkls/BR3_OmC_SUMMERmean_01jun_31aug.pkl", 'wb'))

# print(np.shape(BR_OmC_summer_mean))

# #pi3

# start ='2015-06-20'
# end ='2015-09-22'

# start_run = arrow.get(start)
# end_run = arrow.get(end)

# arrow_array = []

# for r in arrow.Arrow.span_range('day', start_run, end_run):
#     arrow_array.append(r)

# dayslen = len(arrow_array)

# BR_OmC_summer = np.zeros([dayslen,40,898,398])

# for i in range(0,dayslen):

#     tdate = arrow_array[i][0]
#     ymd = tdate.format('YYYYMMDD')

#     if i%10 == 0:
#         print(ymd)
#     t_pco2 = nc.Dataset('//data/tjarniko/results/BASERUN_EXP/Oma_calc/PI3_rr_OmA_plus_'+ymd+'.nc')
#     t_OmC = t_pco2['model_output']['OmC'][:,:,:]
#     BR_OmC_summer[i,:,:,:] = t_OmC

# BR_OmC_summer_mean = np.nanmean(BR_OmC_summer,axis=0)
# pickle.dump(BR_OmC_summer_mean, open("./pkls/PI3rr_OmC_SUMMERmean_20jun_22sep.pkl", 'wb'))
# print(np.shape(BR_OmC_summer_mean))

# start ='2015-06-01'
# end ='2015-08-31'

# start_run = arrow.get(start)
# end_run = arrow.get(end)

# arrow_array = []

# for r in arrow.Arrow.span_range('day', start_run, end_run):
#     arrow_array.append(r)

# dayslen = len(arrow_array)

# BR_OmC_summer = np.zeros([dayslen,40,898,398])

# for i in range(0,dayslen):

#     tdate = arrow_array[i][0]
#     ymd = tdate.format('YYYYMMDD')

#     if i%10 == 0:
#         print(ymd)
#     t_pco2 = nc.Dataset('//data/tjarniko/results/BASERUN_EXP/Oma_calc/PI3_rr_OmA_plus_'+ymd+'.nc')
#     t_OmC = t_pco2['model_output']['OmC'][:,:,:]
#     BR_OmC_summer[i,:,:,:] = t_OmC

# BR_OmC_summer_mean = np.nanmean(BR_OmC_summer,axis=0)
# pickle.dump(BR_OmC_summer_mean, open("./pkls/PI3rr_OmC_SUMMERmean_01jun_31aug.pkl", 'wb'))
# print(np.shape(BR_OmC_summer_mean))

# %% [markdown]
# # code for extracting OmA averages -winter
#
# #### - BR3 winter - dec 21 - mar 19 and dec 1- feb 28
# #### - PI3rr winter - dec 21 - mar 19 and dec 1- feb 28
#
# ## need to do extraction for PI3rr

# %%
# #winter - dec 21 to march 19

# start ='2015-12-21'
# end ='2015-12-31'

# start_run = arrow.get(start)
# end_run = arrow.get(end)

# arrow_array1 = []

# for r in arrow.Arrow.span_range('day', start_run, end_run):
#     arrow_array1.append(r)
# dayslen = len(arrow_array1)

# BR_oma_winter1 = np.zeros([dayslen,40,898,398])

# for i in range(0,dayslen):

#     tdate = arrow_array1[i][0]
#     ymd = tdate.format('YYYYMMDD')

#     if i%10 == 0:
#         print(ymd)
#     t_pco2 = nc.Dataset('//data/tjarniko/results/BASERUN_EXP/Oma_calc/BR3_OmA_plus_'+ymd+'.nc')
#     t_Oma = t_pco2['model_output']['OmC'][:,:,:]
#     BR_oma_winter1[i,:,:,:] = t_Oma

# start ='2015-01-01'
# end ='2015-03-19'

# start_run = arrow.get(start)
# end_run = arrow.get(end)
# arrow_array2 = []

# for r in arrow.Arrow.span_range('day', start_run, end_run):
#     arrow_array2.append(r)
# dayslen = len(arrow_array2)

# BR_oma_winter2 = np.zeros([dayslen,40,898,398])

# for i in range(0,dayslen):

#     tdate = arrow_array2[i][0]
#     ymd = tdate.format('YYYYMMDD')

#     if i%10 == 0:
#         print(ymd)
#     t_pco2 = nc.Dataset('//data/tjarniko/results/BASERUN_EXP/Oma_calc/BR3_OmA_plus_'+ymd+'.nc')
#     t_Oma = t_pco2['model_output']['OmC'][:,:,:]
#     BR_oma_winter2[i,:,:,:] = t_Oma

# BR_oma_winter = np.concatenate((BR_oma_winter1,BR_oma_winter2),axis=0)
# print(np.shape(BR_oma_winter))
# BR_oma_winter_mean = np.nanmean(BR_oma_winter,axis=0)
# pickle.dump(BR_oma_winter_mean, open("./pkls/BR3_OmC_WINTERmean_21dec_19mar.pkl", 'wb'))


# #winter - dec 1 to feb 28

# start ='2015-12-01'
# end ='2015-12-31'

# start_run = arrow.get(start)
# end_run = arrow.get(end)

# arrow_array1 = []

# for r in arrow.Arrow.span_range('day', start_run, end_run):
#     arrow_array1.append(r)
# dayslen = len(arrow_array1)

# BR_oma_winter1 = np.zeros([dayslen,40,898,398])

# for i in range(0,dayslen):

#     tdate = arrow_array1[i][0]
#     ymd = tdate.format('YYYYMMDD')

#     if i%10 == 0:
#         print(ymd)
#     t_pco2 = nc.Dataset('//data/tjarniko/results/BASERUN_EXP/Oma_calc/BR3_OmA_plus_'+ymd+'.nc')
#     t_Oma = t_pco2['model_output']['OmC'][:,:,:]
#     BR_oma_winter1[i,:,:,:] = t_Oma

# start ='2015-01-01'
# end ='2015-02-28'

# start_run = arrow.get(start)
# end_run = arrow.get(end)
# arrow_array2 = []

# for r in arrow.Arrow.span_range('day', start_run, end_run):
#     arrow_array2.append(r)
# dayslen = len(arrow_array2)

# BR_oma_winter2 = np.zeros([dayslen,40,898,398])

# for i in range(0,dayslen):

#     tdate = arrow_array2[i][0]
#     ymd = tdate.format('YYYYMMDD')

#     if i%10 == 0:
#         print(ymd)
#     t_pco2 = nc.Dataset('//data/tjarniko/results/BASERUN_EXP/Oma_calc/BR3_OmA_plus_'+ymd+'.nc')
#     t_Oma = t_pco2['model_output']['OmC'][:,:,:]
#     BR_oma_winter2[i,:,:,:] = t_Oma

# BR_oma_winter = np.concatenate((BR_oma_winter1,BR_oma_winter2),axis=0)
# print(np.shape(BR_oma_winter))
# BR_oma_winter_mean = np.nanmean(BR_oma_winter,axis=0)
# pickle.dump(BR_oma_winter_mean, open("./pkls/BR3_OmC_WINTERmean_01dec_28feb.pkl", 'wb'))

# %%
# #winter - dec 21 to march 19

# start ='2015-12-21'
# end ='2015-12-31'

# start_run = arrow.get(start)
# end_run = arrow.get(end)

# arrow_array1 = []

# for r in arrow.Arrow.span_range('day', start_run, end_run):
#     arrow_array1.append(r)
# dayslen = len(arrow_array1)

# BR_oma_winter1 = np.zeros([dayslen,40,898,398])

# for i in range(0,dayslen):

#     tdate = arrow_array1[i][0]
#     ymd = tdate.format('YYYYMMDD')

#     if i%10 == 0:
#         print(ymd)
#     t_pco2 = nc.Dataset('//data/tjarniko/results/BASERUN_EXP/Oma_calc/PI3_rr_OmA_plus_'+ymd+'.nc')
#     t_Oma = t_pco2['model_output']['OmC'][:,:,:]
#     BR_oma_winter1[i,:,:,:] = t_Oma

# start ='2015-01-01'
# end ='2015-03-19'

# start_run = arrow.get(start)
# end_run = arrow.get(end)
# arrow_array2 = []

# for r in arrow.Arrow.span_range('day', start_run, end_run):
#     arrow_array2.append(r)
# dayslen = len(arrow_array2)

# BR_oma_winter2 = np.zeros([dayslen,40,898,398])

# for i in range(0,dayslen):

#     tdate = arrow_array2[i][0]
#     ymd = tdate.format('YYYYMMDD')

#     if i%10 == 0:
#         print(ymd)
#     t_pco2 = nc.Dataset('//data/tjarniko/results/BASERUN_EXP/Oma_calc/PI3_rr_OmA_plus_'+ymd+'.nc')
#     t_Oma = t_pco2['model_output']['OmC'][:,:,:]
#     BR_oma_winter2[i,:,:,:] = t_Oma

# BR_oma_winter = np.concatenate((BR_oma_winter1,BR_oma_winter2),axis=0)
# print(np.shape(BR_oma_winter))
# BR_oma_winter_mean = np.nanmean(BR_oma_winter,axis=0)
# pickle.dump(BR_oma_winter_mean, open("./pkls/PI3rr_OmC_WINTERmean_21dec_19mar.pkl", 'wb'))


# #winter - dec 1 to feb 28

# start ='2015-12-01'
# end ='2015-12-31'

# start_run = arrow.get(start)
# end_run = arrow.get(end)

# arrow_array1 = []

# for r in arrow.Arrow.span_range('day', start_run, end_run):
#     arrow_array1.append(r)
# dayslen = len(arrow_array1)

# BR_oma_winter1 = np.zeros([dayslen,40,898,398])

# for i in range(0,dayslen):

#     tdate = arrow_array1[i][0]
#     ymd = tdate.format('YYYYMMDD')

#     if i%10 == 0:
#         print(ymd)
#     t_pco2 = nc.Dataset('//data/tjarniko/results/BASERUN_EXP/Oma_calc/PI3_rr_OmA_plus_'+ymd+'.nc')
#     t_Oma = t_pco2['model_output']['OmC'][:,:,:]
#     BR_oma_winter1[i,:,:,:] = t_Oma

# start ='2015-01-01'
# end ='2015-02-28'

# start_run = arrow.get(start)
# end_run = arrow.get(end)
# arrow_array2 = []

# for r in arrow.Arrow.span_range('day', start_run, end_run):
#     arrow_array2.append(r)
# dayslen = len(arrow_array2)

# BR_oma_winter2 = np.zeros([dayslen,40,898,398])

# for i in range(0,dayslen):

#     tdate = arrow_array2[i][0]
#     ymd = tdate.format('YYYYMMDD')

#     if i%10 == 0:
#         print(ymd)
#     t_pco2 = nc.Dataset('//data/tjarniko/results/BASERUN_EXP/Oma_calc/PI3_rr_OmA_plus_'+ymd+'.nc')
#     t_Oma = t_pco2['model_output']['OmC'][:,:,:]
#     BR_oma_winter2[i,:,:,:] = t_Oma

# BR_oma_winter = np.concatenate((BR_oma_winter1,BR_oma_winter2),axis=0)
# print(np.shape(BR_oma_winter))
# BR_oma_winter_mean = np.nanmean(BR_oma_winter,axis=0)
# pickle.dump(BR_oma_winter_mean, open("./pkls/PI3rr_OmC_WINTERmean_01dec_28feb.pkl", 'wb'))

# %%
BR3_summer_3mon = pickle.load(open('./pkls/BR3_OmC_SUMMERmean_01jun_31aug.pkl', 'rb'))  
BR3_summer_calend = pickle.load(open('./pkls/BR3_OmC_SUMMERmean_20jun_22sep.pkl', 'rb'))  
BR3_winter_3mon = pickle.load(open('./pkls/BR3_OmC_WINTERmean_01dec_28feb.pkl', 'rb'))  
BR3_winter_calend = pickle.load(open('./pkls/BR3_OmC_WINTERmean_21dec_19mar.pkl', 'rb'))  

PI3rr_summer_3mon = pickle.load(open('./pkls/PI3rr_OmC_SUMMERmean_01jun_31aug.pkl', 'rb'))  
PI3rr_summer_calend = pickle.load(open('./pkls/PI3rr_OmC_SUMMERmean_20jun_22sep.pkl', 'rb'))  
PI3rr_winter_3mon = pickle.load(open('./pkls/PI3rr_OmC_WINTERmean_01dec_28feb.pkl', 'rb'))  
PI3rr_winter_calend = pickle.load(open('./pkls/PI3rr_OmC_WINTERmean_21dec_19mar.pkl', 'rb'))

# %% [markdown]
# ## calendar year definitions of summer and winter comparisons

# %%
bathy = nc.Dataset('/data/tjarniko/MEOPAR/grid/bathymetry_201702.nc')
mesh = nc.Dataset('/data/tjarniko/MEOPAR/grid/mesh_mask201702.nc')
ts = 14 # title font
fs = 10.5 # all other font sizes
fact = 1
fig = plt.figure(figsize=(12*fact, 9.5*fact))

ax1 = plt.subplot2grid((3,4), (0,0), colspan=2, rowspan=1)
cbar = \
vis.contour_thalweg(ax1, PI3rr_summer_calend, bathy, mesh,\
                    np.arange(0.0, 2.0, 0.05), cmap = cmocean.cm.balance_r)
ax1.set_title('$\Omega_C$ Summer Average (PI Run)',fontsize = ts)
cbar.ax.tick_params(labelsize=fs) 
cbar.set_label('$\Omega_C$', fontsize = fs)
ax1.tick_params(axis='both', which='major', labelsize=fs)
ax1.set_xlabel('km along thalweg')

ax2 = plt.subplot2grid((3,4), (0,2), colspan=2, rowspan=1)
cbar = \
vis.contour_thalweg(ax2, PI3rr_winter_calend, bathy, mesh,\
                    np.arange(0.0, 2.0, 0.05), cmap = cmocean.cm.balance_r)
ax2.set_title('$\Omega_C$ Winter Average (PI Run)',fontsize = ts)
cbar.ax.tick_params(labelsize=fs) 
cbar.set_label('$\Omega_C$', fontsize = fs)
ax2.tick_params(axis='both', which='major', labelsize=fs)
ax2.set_xticklabels([])
ax2.set_xlabel('')
ax2.set_xlabel('km along thalweg')

ax3 = plt.subplot2grid((3,4), (1,0), colspan=2, rowspan=1)
cbar = \
vis.contour_thalweg(ax3, BR3_summer_calend, bathy, mesh,\
                    np.arange(0.0, 2.0, 0.05), cmap = cmocean.cm.balance_r)
ax3.set_title('$\Omega_C$ Summer Average (BR Run)',fontsize = ts)
cbar.ax.tick_params(labelsize=fs) 
cbar.set_label('$\Omega_C$', fontsize = fs)
ax3.tick_params(axis='both', which='major', labelsize=fs)
ax3.set_xlabel('km along thalweg')

ax4 = plt.subplot2grid((3,4), (1,2), colspan=2, rowspan=1)
cbar = \
vis.contour_thalweg(ax4, BR3_winter_calend, bathy, mesh,\
                    np.arange(0.0, 2.0, 0.05), cmap = cmocean.cm.balance_r)
ax4.set_title('$\Omega_C$ Winter Average (BR Run)',fontsize = ts)
cbar.ax.tick_params(labelsize=fs) 
cbar.set_label('$\Omega_C$', fontsize = fs)
ax4.tick_params(axis='both', which='major', labelsize=fs)
ax4.set_xlabel('km along thalweg')

ax5 = plt.subplot2grid((3,4), (2,0), colspan=4, rowspan=1)
  
fig.tight_layout()

# %% [markdown]
# # 3 month (winter = dec-feb, summer = jun-aug) definition of seasons

# %%
bathy = nc.Dataset('/data/tjarniko/MEOPAR/grid/bathymetry_201702.nc')
mesh = nc.Dataset('/data/tjarniko/MEOPAR/grid/mesh_mask201702.nc')
ts = 14 # title font
fs = 10.5 # all other font sizes
fact = 1
fig = plt.figure(figsize=(12*fact, 9.5*fact))

ax1 = plt.subplot2grid((3,4), (0,0), colspan=2, rowspan=1)
cbar = \
vis.contour_thalweg(ax1, PI3rr_summer_3mon, bathy, mesh,\
                    np.arange(0.0, 2.0, 0.05), cmap = cmocean.cm.balance_r)
ax1.set_title('$\Omega_C$ Summer Average (PI Run)',fontsize = ts)
cbar.ax.tick_params(labelsize=fs) 
cbar.set_label('$\Omega_C$', fontsize = fs)
ax1.tick_params(axis='both', which='major', labelsize=fs)
ax1.set_xlabel('km along thalweg')

ax2 = plt.subplot2grid((3,4), (0,2), colspan=2, rowspan=1)
cbar = \
vis.contour_thalweg(ax2, PI3rr_winter_3mon, bathy, mesh,\
                    np.arange(0.0, 2.0, 0.05), cmap = cmocean.cm.balance_r)
ax2.set_title('$\Omega_C$ Winter Average (PI Run)',fontsize = ts)
cbar.ax.tick_params(labelsize=fs) 
cbar.set_label('$\Omega_C$', fontsize = fs)
ax2.tick_params(axis='both', which='major', labelsize=fs)
ax2.set_xticklabels([])
ax2.set_xlabel('')
ax2.set_xlabel('km along thalweg')

ax3 = plt.subplot2grid((3,4), (1,0), colspan=2, rowspan=1)
cbar = \
vis.contour_thalweg(ax3, BR3_summer_3mon, bathy, mesh,\
                    np.arange(0.0, 2.0, 0.05), cmap = cmocean.cm.balance_r)
ax3.set_title('$\Omega_C$ Summer Average (BR Run)',fontsize = ts)
cbar.ax.tick_params(labelsize=fs) 
cbar.set_label('$\Omega_C$', fontsize = fs)
ax3.tick_params(axis='both', which='major', labelsize=fs)
ax3.set_xlabel('km along thalweg')

ax4 = plt.subplot2grid((3,4), (1,2), colspan=2, rowspan=1)
cbar = \
vis.contour_thalweg(ax4, BR3_winter_3mon, bathy, mesh,\
                    np.arange(0.0, 2.0, 0.05), cmap = cmocean.cm.balance_r)
ax4.set_title('$\Omega_C$ Winter Average (BR Run)',fontsize = ts)
cbar.ax.tick_params(labelsize=fs) 
cbar.set_label('$\Omega_C$', fontsize = fs)
ax4.tick_params(axis='both', which='major', labelsize=fs)
ax4.set_xlabel('km along thalweg')

ax5 = plt.subplot2grid((3,4), (2,0), colspan=4, rowspan=1)
  
fig.tight_layout()

# %%
print('done')
# Out:
# done

# %%
print ('no, really done')
print('dear github please render this properly')
# Out:
# no, really done
# dear github please render this properly

# %%
print(2*2*2)
# Out:
# 8
