# %%
from IPython.display import Image

# %% [markdown]
# ## Summary notebook for expanded model DIC and TA evaluation
#
# Model metrics: bias, RMSE, WSS, ratio of standard deviations.
#
# This set of analyses is in response to Reviewer 1

# %% [markdown]
# ## Part 1: plots for research group
#
#
# - by-region and year evaluation for each of DIC, TA, and OmegaA in both salinity and depth space'
#
#         depth space: match model day, model month, and model depth
#         salinity space: match model day, model month, and interpolate DIC/TA to model salinity
#             (ie find the model DIC and TA interpolated to where between the two bounding model salinities
#             the observational salinity lies
#             **in salinity space, when Omega was calculated,
#             it used observation P,S,T for both model and obs omega**
#
# - 4 observational datasets available: GRL, D14, D15, and COMB (D14 - data from 2014; COMB - all data combined)
#
# - n of available DIC/TA observations in depth space:
#
#         COMB: 567 (goes down to 436-466 in salinity space - sometimes our salinity is out of the model)
#         GRL: 420
#         D14: 72
#         D15: 75
#
# - In the below plots, FULL LINES are all available data, DASHED are GRL data, symbols are D14 and D15

# %% [markdown]
# ## DIC metrics
#
# - overall very good (blue line) - Jdf and N Strait biased high, haro biased low
# - RMSE improves with evaluation by salinity, bias gets worse, WSS pretty similar, ratio gets better
# - 2017 is a weird year in salinity space - but no. of observations not meaningfully different!
# - in 2017, in salinity space, we are biased high...
# - year-specific evaluation (eg year 2014 vs D14 and 2015 vs D15) has only sometimes lower bias and lower rmse - but low n
# - addition of new data doesn't meaningfully improve evaluation from just GRL data

# %%
Image('./extracted_calculated/DIC_stats.jpg')

# %% [markdown]
# ## TA metrics
#
# - overall biased high - ~27 umol/L. Highest bias in NSog - potentially due to rivers (boundary conditions look ok)
# - RMSE improves with evaluation by salinity, bias gets a bit better, WSS gets a lot better, ratio gets better
# - 2017 is a weird year in salinity space - but no. of observations not meaningfully different!
# - in 2017, in salinity space, we are biased high...
# - year-specific evaluation (eg year 2014 vs D14 and 2015 vs D15) has typically lower bias and lower rmse (sometimes by a lot!) - but low n
# - addition of new data doesn't meaningfully improve evaluation from just GRL data

# %%
Image('./extracted_calculated/TA_stats.jpg')

# %% [markdown]
# ## Omega metrics
#
# - overall biased high - except in JdF
# - addition of new data doesn't meaningfully improve evaluation from just GRL data
# - ratio of std deviation is bang on
# - WSS understandably worsens

# %%
Image('./extracted_calculated/OmegaA_stats.jpg')

# %% [markdown]
# ## Bias with depth
#
# - TA improves with depth (goes from too much to just a bit too much),
# - DIC gets worse with depth (goes from great to too little DIC)
# - TA bias - DIC bias gets a bit worse with depth
# - Close to half of the observations are in the top 50 meters, as we know - the deep is unobserved.

# %%
Image('./extracted_calculated/biaswithdepth.jpg')

# %% [markdown]
# ## What to show Reviewer 1:
#
# The above is clearly too much detail - we understand quite a bit more about the model, but don't need to show all of it.
#
# - For each of Omega, DIC, and TA:
#     - scatterplots of mod vs obs for each of 5 years, plus [mean of 5 years mod] vs obs (3 plots, 6 subplots each)
# - For each of Omega, DIC, and TA:
#     - plot with subplot of bias, RMSE, WSS, ratio of std devs - in depth space, for COMB dataset
#     - (3 plots with 4 subplots each, alternately could just be one plot with 12 subplots (maybe easier!)
#     - for TA ONLY, show this in both depth space and salinity space
#     - only full-domain metrics (blue line) - regional metrics strike me as too much detail?
# - Salinity and TA evaluation plots explicitly shown, with metrics on plot - would ask Elise for. (right now it's referred to but it's very good and sal. is dominant control)
