# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

# %matplotlib inline

# %%
mesh = xr.open_dataset('/home/sallen/MEOPAR/grid/mesh_mask201702.nc')

# %%
mesh.mbathy.plot();

# %%
mbathys = np.array(mesh.mbathy[0])
mbathys.shape
# Out:
# (898, 398)

# %%
plt.hist(mbathys.flatten(), bins=range(39));
