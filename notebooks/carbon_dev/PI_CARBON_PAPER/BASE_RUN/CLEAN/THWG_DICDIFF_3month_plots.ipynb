# %%
from IPython.display import Image
Image(filename='./jpgs_3month_BR-PI/JanFeb2015_DICdiff.jpg')

# %%
from IPython.display import Image
Image(filename='./jpgs_3month_BR-PI/MarApr2015_DICdiff.jpg')

# %%
from IPython.display import Image
Image(filename='./jpgs_3month_BR-PI/MayJul2015_DICdiff.jpg')

# %%
from IPython.display import Image
Image(filename='./jpgs_3month_BR-PI/AugOct2015_DICdiff.jpg')

# %%
from IPython.display import Image
Image(filename='./jpgs_3month_BR-PI/NovDec2015_DICdiff.jpg')
