# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
from __future__ import print_function
from numpy import *
from scipy import *
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
import netCDF4 as nc
import numpy as np
import scipy as sp
import warnings
warnings.filterwarnings('ignore')

import seawater
import datetime as dt
""
from salishsea_tools import (
    nc_tools,
    viz_tools,
    geo_tools,
    tidetools
)

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import matplotlib.patches as patches
plt.style.use('seaborn-whitegrid')
import netCDF4 as nc

import cmocean as cm
import glob
import sys
sys.path.append('/data/tjarniko/mocsy')
sys.path.append('/data/tjarniko/MEOPAR/at3/notebooks/carbon_dev/CCCmaDEV/CCCma_src')
import mocsy
import CCCma
import CCCma_stations as cs
from matplotlib import reload
import arrow
import gsw
# %matplotlib inline

import xarray as xr
from datetime import datetime
from salishsea_tools import grid_tools, viz_tools

# %%
DIC = np.arange(1900,2300,50)
TA_1900 = np.zeros_like(DIC)
TA_1900[:]=1900
zero = np.zeros_like(DIC)
ttemp = np.zeros_like(DIC)
tsal = np.zeros_like(DIC)
ttemp[:]=7
tsal[:]=29
mn = 0
mx = 1000

TA_1950 = np.zeros_like(DIC)
TA_1950[:]=1950
TA_2000 = np.zeros_like(DIC)
TA_2000[:]=2000
TA_2050 = np.zeros_like(DIC)
TA_2050[:]=2050
TA_2100 = np.zeros_like(DIC)
TA_2100[:]=2100
TA_2150 = np.zeros_like(DIC)
TA_2150[:]=2150
TA_2200 = np.zeros_like(DIC)
TA_2200[:]=2200
TA_2250 = np.zeros_like(DIC)
TA_2250[:]=2250
TA_2300 = np.zeros_like(DIC)
TA_2300[:]=2300
response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_1900*1e-3, dic=DIC*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2_1900,fco2,co2,hco3,co3,OmegaA_1900,OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_1950*1e-3, dic=DIC*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2_1950,fco2,co2,hco3,co3,OmegaA_1950,OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2000*1e-3, dic=DIC*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2_2000,fco2,co2,hco3,co3,OmegaA_2000,OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2050*1e-3, dic=DIC*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2_2050,fco2,co2,hco3,co3,OmegaA_2050,OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2100*1e-3, dic=DIC*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2_2100,fco2,co2,hco3,co3,OmegaA_2100,OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2150*1e-3, dic=DIC*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2_2150,fco2,co2,hco3,co3,OmegaA_2150,OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2200*1e-3, dic=DIC*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2_2200,fco2,co2,hco3,co3,OmegaA_2200,OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2250*1e-3, dic=DIC*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2_2250,fco2,co2,hco3,co3,OmegaA_2250,OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2300*1e-3, dic=DIC*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2_2300,fco2,co2,hco3,co3,OmegaA_2300,OmegaC,BetaD,DENis,p,Tis = response_tup


plt.scatter(DIC, TA_1900, c=pco2_1900, s=100, cmap=cm.cm.balance, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_1950, c=pco2_1950, s=100, cmap=cm.cm.balance, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2000, c=pco2_2000, s=100, cmap=cm.cm.balance, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2050, c=pco2_2050, s=100, cmap=cm.cm.balance, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2100, c=pco2_2100, s=100, cmap=cm.cm.balance, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2150, c=pco2_2150, s=100, cmap=cm.cm.balance, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2200, c=pco2_2200, s=100, cmap=cm.cm.balance, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2250, c=pco2_2250, s=100, cmap=cm.cm.balance, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2300, c=pco2_2300, s=100, cmap=cm.cm.balance, vmin = mn, vmax = mx)

plt.title('At T = 7, S = 29,\n and a given DIC and TA, \nthis is the pco2')

plt.colorbar()
plt.show()

# %%
pert=10
DIC_p = np.arange(1900,2300,50)+pert
mn = -200
mx = 200


response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_1900*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,P_pco2_1900,fco2,co2,hco3,co3,P_OmegaA_1900,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_1950*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,P_pco2_1950,fco2,co2,hco3,co3,P_OmegaA_1950,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2000*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,P_pco2_2000,fco2,co2,hco3,co3,P_OmegaA_2000,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2050*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,P_pco2_2050,fco2,co2,hco3,co3,P_OmegaA_2050,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2100*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,P_pco2_2100,fco2,co2,hco3,co3,P_OmegaA_2100,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2150*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,P_pco2_2150,fco2,co2,hco3,co3,P_OmegaA_2150,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2200*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,P_pco2_2200,fco2,co2,hco3,co3,P_OmegaA_2200,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2250*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,P_pco2_2250,fco2,co2,hco3,co3,P_OmegaA_2250,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2300*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,P_pco2_2300,fco2,co2,hco3,co3,P_OmegaA_2300,P_OmegaC,BetaD,DENis,p,Tis = response_tup


plt.scatter(DIC, TA_1900, c=pco2_1900-P_pco2_1900, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mn)
plt.scatter(DIC, TA_1950, c=pco2_1950-P_pco2_1950, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2000, c=pco2_2000-P_pco2_2000, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2050, c=pco2_2050-P_pco2_2050, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2100, c=pco2_2100-P_pco2_2100, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2150, c=pco2_2150-P_pco2_2150, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2200, c=pco2_2200-P_pco2_2200, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2250, c=pco2_2250-P_pco2_2250, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2300, c=pco2_2300-P_pco2_2300, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.title('At T = 7, S = 29,\n and a given DIC and TA, \nif DIC increases by '+str(pert)+\
         ',\n Omega decreases by this amount')
plt.xlabel('DIC')
plt.ylabel('TA')
plt.colorbar()
plt.show()

# %%
pert=20
DIC_p = np.arange(1900,2300,50)+pert
mn = 0
mx = 0.2


response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_1900*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2,fco2,co2,hco3,co3,P_OmegaA_1900,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_1950*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2,fco2,co2,hco3,co3,P_OmegaA_1950,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2000*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2,fco2,co2,hco3,co3,P_OmegaA_2000,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2050*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2,fco2,co2,hco3,co3,P_OmegaA_2050,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2100*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2,fco2,co2,hco3,co3,P_OmegaA_2100,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2150*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2,fco2,co2,hco3,co3,P_OmegaA_2150,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2200*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2,fco2,co2,hco3,co3,P_OmegaA_2200,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2250*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2,fco2,co2,hco3,co3,P_OmegaA_2250,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2300*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2,fco2,co2,hco3,co3,P_OmegaA_2300,P_OmegaC,BetaD,DENis,p,Tis = response_tup


plt.scatter(DIC, TA_1900, c=OmegaA_1900-P_OmegaA_1900, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mn)
plt.scatter(DIC, TA_1950, c=OmegaA_1950-P_OmegaA_1950, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2000, c=OmegaA_2000-P_OmegaA_2000, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2050, c=OmegaA_2050-P_OmegaA_2050, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2100, c=OmegaA_2100-P_OmegaA_2100, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2150, c=OmegaA_2150-P_OmegaA_2150, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2200, c=OmegaA_2200-P_OmegaA_2200, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2250, c=OmegaA_2250-P_OmegaA_2250, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2300, c=OmegaA_2300-P_OmegaA_2300, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.title('At T = 7, S = 29,\n and a given DIC and TA, \nif DIC increases by '+str(pert)+\
         ',\n Omega decreases by this amount')
plt.xlabel('DIC')
plt.ylabel('TA')
plt.colorbar()
plt.show()

# %%
pert=50
DIC_p = np.arange(1900,2300,50)+pert
mn = 0
mx = 0.5


response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_1900*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2,fco2,co2,hco3,co3,P_OmegaA_1900,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_1950*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2,fco2,co2,hco3,co3,P_OmegaA_1950,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2000*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2,fco2,co2,hco3,co3,P_OmegaA_2000,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2050*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2,fco2,co2,hco3,co3,P_OmegaA_2050,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2100*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2,fco2,co2,hco3,co3,P_OmegaA_2100,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2150*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2,fco2,co2,hco3,co3,P_OmegaA_2150,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2200*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2,fco2,co2,hco3,co3,P_OmegaA_2200,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2250*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2,fco2,co2,hco3,co3,P_OmegaA_2250,P_OmegaC,BetaD,DENis,p,Tis = response_tup

response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=TA_2300*1e-3, dic=DIC_p*1e-3, 
                   sil=zero, phos=zero, patm=zero, depth=zero, lat=zero, 
                    optcon='mol/m3', optt='Tinsitu', optp='m',
                    optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
pH,pco2,fco2,co2,hco3,co3,P_OmegaA_2300,P_OmegaC,BetaD,DENis,p,Tis = response_tup


plt.scatter(DIC, TA_1900, c=OmegaA_1900-P_OmegaA_1900, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mn)
plt.scatter(DIC, TA_1950, c=OmegaA_1950-P_OmegaA_1950, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2000, c=OmegaA_2000-P_OmegaA_2000, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2050, c=OmegaA_2050-P_OmegaA_2050, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2100, c=OmegaA_2100-P_OmegaA_2100, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2150, c=OmegaA_2150-P_OmegaA_2150, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2200, c=OmegaA_2200-P_OmegaA_2200, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2250, c=OmegaA_2250-P_OmegaA_2250, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.scatter(DIC, TA_2300, c=OmegaA_2300-P_OmegaA_2300, s=100, cmap=cm.cm.matter, vmin = mn, vmax = mx)
plt.title('At T = 7, S = 29,\n and a given DIC and TA, \nif DIC increases by '+str(pert)+\
         ',\n Omega decreases by this amount')
plt.xlabel('DIC')
plt.ylabel('TA')
plt.colorbar()
plt.show()

# %% [markdown]
# ## sanity check - TA-DIC increases and effects of
# ## 10 umol DIC perturbation on Omega

# %%
dic = np.arange(1700,2300,100)
for i in range(0,len(dic)):
    ttemp = 7
    tsal = 29
    tdic = dic[i]
    talk = 2100
    pert = 10
    response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=talk*1e-3, dic=tdic*1e-3, 
                       sil=0, phos=0, patm=0, depth=0, lat=0, 
                        optcon='mol/m3', optt='Tinsitu', optp='m',
                        optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
    pH,pco2,fco2,co2,hco3,co3,OmegaA,OmegaC,BetaD,DENis,p,Tis = response_tup
    response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=talk*1e-3, dic=(tdic+pert)*1e-3, 
                       sil=0, phos=0, patm=0, depth=0, lat=0, 
                        optcon='mol/m3', optt='Tinsitu', optp='m',
                        optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
    pH,pco2,fco2,co2,hco3,co3,OmegaA_p,OmegaC,BetaD,DENis,p,Tis = response_tup
    print('')
    print('TA-DIC: '+str(talk-tdic))
    print('DIC: '+str(tdic)+', TA: '+str(talk)+', Omega: '+str(OmegaA[0]))
    print('If DIC increased by '+str(pert)+\
          ', Omega decrease by: '+ str(OmegaA[0]-OmegaA_p[0]))

# %% [markdown]
# ## sanity check - TA-DIC increases and effects of
# ## 50 umol DIC perturbation on Omega

# %%
dic = np.arange(1700,2300,100)
for i in range(0,len(dic)):
    ttemp = 7
    tsal = 29
    tdic = dic[i]
    talk = 2100
    pert = 50
    response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=talk*1e-3, dic=tdic*1e-3, 
                       sil=0, phos=0, patm=0, depth=0, lat=0, 
                        optcon='mol/m3', optt='Tinsitu', optp='m',
                        optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
    pH,pco2,fco2,co2,hco3,co3,OmegaA,OmegaC,BetaD,DENis,p,Tis = response_tup
    response_tup = mocsy.mvars(temp=ttemp, sal=tsal, alk=talk*1e-3, dic=(tdic+pert)*1e-3, 
                       sil=0, phos=0, patm=0, depth=0, lat=0, 
                        optcon='mol/m3', optt='Tinsitu', optp='m',
                        optb = 'l10', optk1k2='m10', optkf = 'dg', optgas = 'Pinsitu')
    pH,pco2_p,fco2,co2,hco3,co3,OmegaA_p,OmegaC,BetaD,DENis,p,Tis = response_tup
    print('')
    print('TA-DIC: '+str(talk-tdic))
    print('DIC: '+str(tdic)+', TA: '+str(talk)+', Omega: '+str(OmegaA[0]))
    print('If DIC increased by '+str(pert)+\
          ', Omega decrease by: '+ str(OmegaA[0]-OmegaA_p[0]))
    print('If DIC increased by '+str(pert)+\
          ', pco2 decrease by: '+ str(pco2[0]-pco2_p[0]))
# Out:
# TA-DIC: 400
# DIC: 1700, TA: 2100, Omega: 4.038816476975671
# If DIC increased by 50, Omega decrease by: 0.4947432186945795
# If DIC increased by 50, pco2 decrease by: -21.8254881969592
#
# TA-DIC: 300
# DIC: 1800, TA: 2100, Omega: 3.054755322340945
# If DIC increased by 50, Omega decrease by: 0.4818517694548574
# If DIC increased by 50, pco2 decrease by: -40.49316825293894
#
# TA-DIC: 200
# DIC: 1900, TA: 2100, Omega: 2.1020061416684817
# If DIC increased by 50, Omega decrease by: 0.45351357763654043
# If DIC increased by 50, pco2 decrease by: -89.07400620735791
#
# TA-DIC: 100
# DIC: 2000, TA: 2100, Omega: 1.2248061334024387
# If DIC increased by 50, Omega decrease by: 0.37072819221317344
# If DIC increased by 50, pco2 decrease by: -245.17605462931135
#
# TA-DIC: 0
# DIC: 2100, TA: 2100, Omega: 0.5680726832934967
# If DIC increased by 50, Omega decrease by: 0.18726191058050845
# If DIC increased by 50, pco2 decrease by: -602.247881281467
#
# TA-DIC: -100
# ...
