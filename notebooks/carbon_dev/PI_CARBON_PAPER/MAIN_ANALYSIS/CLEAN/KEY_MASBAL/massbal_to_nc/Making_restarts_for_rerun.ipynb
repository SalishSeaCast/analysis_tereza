# %%
import numpy as np
import netCDF4 as nc

# %% [markdown]
# ## objective - start out all fields except DIC, TA the same as the end of BR2
#
# we are rerunning PI3 and LA3,  starting all fields at the end of BR2 except DIC and TA

# %%
br_restart = nc.Dataset('/data/tjarniko/results/BASERUN_EXP/\
MAIN/BR_2nd_2015/ncs/SKOG_02471040_restart_trc.nc')
pi_restart = nc.Dataset('/data/tjarniko/results/BASERUN_EXP/\
NOT_MAIN_ANALYSIS/PI_ACBC_2015_2/ncs/SKOG_04840560_restart_trc.nc')

la_restart = nc.Dataset('/data/tjarniko/results/BASERUN_EXP/\
NOT_MAIN_ANALYSIS/PI_2nd_2015/LA2_rerun_from26dec15/SKOG_02473200_restart_trc.nc')

# %%
print(br_restart)
print(br_restart['time_counter'][:])
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     file_name: SKOG_02471040_restart_trc.nc
#     TimeStamp: 18/05/2019 21:41:43 -0400
#     dimensions(sizes): x(398), y(898), z(40), t(1)
# ...

# %%
dsin = br_restart

#output file
ncname = 'SKOG_02471040_restart_trc.nc'
dsout = nc.Dataset(ncname, "w", format="NETCDF4")
#Copy dimensions
for dname, the_dim in dsin.dimensions.items():
    print(dname)
    print(len(the_dim))
    dsout.createDimension(dname, len(the_dim) if not the_dim.isunlimited() else None)
# Copy variables
for v_name, varin in dsin.variables.items():
    outVar = dsout.createVariable(v_name, varin.datatype, varin.dimensions)
    print(varin.datatype)
    
    # Copy variable attributes
    outVar.setncatts({k: varin.getncattr(k) for k in varin.ncattrs()})
    
    outVar[:] = varin[:]
    

dsout['TRBDIC'][:] = la_restart['TRBDIC'][:]
dsout['TRBTA'][:] = la_restart['TRBTA'][:]

dsout.close()
# Out:
# x
# 398
# y
# 898
# z
# 40
# t
# 1
# float32
# float32
# float32
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64

# %%
dsin = br_restart

#output file
ncname = 'SKOG_PI3start_04840560_restart_trc.nc'
dsout = nc.Dataset(ncname, "w", format="NETCDF4")
#Copy dimensions
for dname, the_dim in dsin.dimensions.items():
    print(dname)
    print(len(the_dim))
    dsout.createDimension(dname, len(the_dim) if not the_dim.isunlimited() else None)
# Copy variables
for v_name, varin in dsin.variables.items():
    outVar = dsout.createVariable(v_name, varin.datatype, varin.dimensions)
    print(varin.datatype)
    
    # Copy variable attributes
    outVar.setncatts({k: varin.getncattr(k) for k in varin.ncattrs()})
    
    outVar[:] = varin[:]
    

dsout['TRBDIC'][:] = pi_restart['TRBDIC'][:]
dsout['TRBTA'][:] = pi_restart['TRBTA'][:]

dsout.close()

# %%
dsin = br_restart

#output file
ncname = 'SKOG_PI3start_04840560_restart_trc.nc'
dsout = nc.Dataset(ncname, "w", format="NETCDF4")
#Copy dimensions
for dname, the_dim in dsin.dimensions.items():
    print(dname)
    print(len(the_dim))
    dsout.createDimension(dname, len(the_dim) if not the_dim.isunlimited() else None)
# Copy variables
for v_name, varin in dsin.variables.items():
    outVar = dsout.createVariable(v_name, varin.datatype, varin.dimensions)
    print(varin.datatype)
    
    # Copy variable attributes
    outVar.setncatts({k: varin.getncattr(k) for k in varin.ncattrs()})
    
    outVar[:] = varin[:]
    

dsout['TRBDIC'][:] = pi_restart['TRBDIC'][:]
dsout['TRBTA'][:] = pi_restart['TRBTA'][:]

dsout.close()
# Out:
# x
# 398
# y
# 898
# z
# 40
# t
# 1
# float32
# float32
# float32
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# ---------------------------------------------------------------
# KeyboardInterrupt             Traceback (most recent call last)
# <ipython-input-7-64bb9730529c> in <module>
#      17     outVar.setncatts({k: varin.getncattr(k) for k in varin.ncattrs()})
#      18
# ---> 19     outVar[:] = varin[:]
#      20
#      21
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Variable.__getitem__()
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Variable._toma()
#
# ...

# %%
dsin = nc.Dataset('/data/tjarniko/results/BASERUN_EXP/\
MAIN/BR_2nd_2015/ncs/SKOG_02471040_restart.nc')

ncname = 'SKOG_PI3start_04840560_restart.nc'
dsout = nc.Dataset(ncname, "w", format="NETCDF4")
#Copy dimensions
for dname, the_dim in dsin.dimensions.items():
    print(dname)
    print(len(the_dim))
    dsout.createDimension(dname, len(the_dim) if not the_dim.isunlimited() else None)
# Copy variables
for v_name, varin in dsin.variables.items():
    outVar = dsout.createVariable(v_name, varin.datatype, varin.dimensions)
    print(v_name)
    
    # Copy variable attributes
    outVar.setncatts({k: varin.getncattr(k) for k in varin.ncattrs()})
    
    outVar[:] = varin[:]
    


dsout.close()

# %%
dsin = nc.Dataset('/data/tjarniko/results/BASERUN_EXP/\
MAIN/BR_2nd_2015/ncs/SKOG_02471040_restart.nc')

ncname = 'SKOG_LA3start_04840560_restart.nc'
dsout = nc.Dataset(ncname, "w", format="NETCDF4")
#Copy dimensions
for dname, the_dim in dsin.dimensions.items():
    print(dname)
    print(len(the_dim))
    dsout.createDimension(dname, len(the_dim) if not the_dim.isunlimited() else None)
# Copy variables
for v_name, varin in dsin.variables.items():
    outVar = dsout.createVariable(v_name, varin.datatype, varin.dimensions)
    print(v_name)
    
    # Copy variable attributes
    outVar.setncatts({k: varin.getncattr(k) for k in varin.ncattrs()})
    
    outVar[:] = varin[:]
    


dsout.close()
