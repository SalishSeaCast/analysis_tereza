# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
#import all the things

# %reset
import netCDF4 as nc
import matplotlib.pyplot as plt
import datetime
import os
import numpy as np
import cmocean as cm
from salishsea_tools import visualisations as vis
from salishsea_tools import (teos_tools, tidetools, viz_tools)
import xarray as xr 
import subprocess 
import cmocean

# %matplotlib inline
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
baserun = '/data/tjarniko/results/BR_1st_2015/ncs/'

m29 ='SKOG_1d_20150302_20150331_carp_T_20150329-20150329.nc'
m30 ='SKOG_1d_20150302_20150331_carp_T_20150330-20150330.nc'
m31 ='SKOG_1d_20150302_20150331_carp_T_20150331-20150331.nc'
bathy = nc.Dataset('/data/tjarniko/MEOPAR/grid/bathymetry_201702.nc')
mesh = nc.Dataset('/data/tjarniko/MEOPAR/grid/mesh_mask201702.nc')


# fig.suptitle('Mar 29')

# %% [markdown]
# ## BASERUN MARCH 29 (day 88)

# %%
tplt = nc.Dataset(baserun+m29)
i = 0
td29 = tplt['dissolved_inorganic_carbon'][0,:,:,:]
cmap = cm.cm.haline
vmin = 1900
vmax = 2200
stepsize = 0.1
fig,ax = plt.subplots(1,1,figsize=(15,5))
vis.contour_thalweg(ax, td29, bathy, mesh, np.arange(vmin, vmax, stepsize), cmap = cmap)

# %% [markdown]
# ## BASERUN MARCH 30 (day 89)

# %%
tplt = nc.Dataset(baserun+m30)
i = 0
td30 = tplt['dissolved_inorganic_carbon'][0,:,:,:]
cmap = cm.cm.haline
vmin = 1900
vmax = 2200
stepsize = 0.1
fig,ax = plt.subplots(1,1,figsize=(15,5))
vis.contour_thalweg(ax, td30, bathy, mesh, np.arange(vmin, vmax, stepsize), cmap = cmap)

# %% [markdown]
# # BASERUN MARCH 31 (day 90)

# %%
tplt = nc.Dataset(baserun+m31)
i = 0
td31 = tplt['dissolved_inorganic_carbon'][0,:,:,:]
cmap = cm.cm.haline
vmin = 1900
vmax = 2200
stepsize = 0.1
fig,ax = plt.subplots(1,1,figsize=(15,5))
vis.contour_thalweg(ax, td31, bathy, mesh, np.arange(vmin, vmax, stepsize), cmap = cmap)

# %% [markdown]
# # March 31 - March 30

# %%
cmap = cm.cm.balance
vmin = -100
vmax = 100
stepsize = 0.1
fig,ax = plt.subplots(1,1,figsize=(15,5))
vis.contour_thalweg(ax, td31-td30, bathy, mesh, np.arange(vmin, vmax, stepsize), cmap = cmap)

# %% [markdown]
# # mar 30 - mar 29

# %%
cmap = cm.cm.balance
vmin = -100
vmax = 100
stepsize = 0.1
fig,ax = plt.subplots(1,1,figsize=(15,5))
vis.contour_thalweg(ax, td30-td29, bathy, mesh, np.arange(vmin, vmax, stepsize), cmap = cmap)
