# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
plt.style.use('classic')
from matplotlib.patches import Rectangle
import pickle
from cmocean import cm
import warnings
import netCDF4 as nc
import arrow
import glob
import sys
sys.path.append('./bylayer_extract/')
import extract_bylayer_mean_BOXMASK as ebmBOX 
import extract_bylayer_mean as ebm
from importlib import reload
from salishsea_tools import viz_tools

# %matplotlib inline
warnings.simplefilter('ignore')

plt.rcParams.update({'font.size': 13,
                     'xtick.labelsize' : 13,
                     'ytick.labelsize' : 13})

# %%
jdf_x = 85; jdf_y = 325; jdf_col = 'teal'
jdf2_x = 50; jdf2_y = 370; jdf2_col = 'mediumaquamarine'
jdf3_x = 130; jdf3_y = 290; jdf3_col = 'lightseagreen'

cs_x = 250; cs_y = 500; cs_col = 'royalblue'
cs2_x = 280; cs2_y = 440; cs2_col = 'navy'
cs3_x = 220; cs3_y = 540; cs3_col = 'dodgerblue'

haro_x = 230; haro_y = 310; haro_col = 'tomato'
haro2_x = 340; haro2_y = 290; haro2_col = 'firebrick'
haro3_x = 260; haro3_y = 335; haro3_col = 'indianred'


ns_x = 160; ns_y = 680; ns_col = 'olive'
ns2_x = 150; ns2_y = 640; ns2_col = 'yellowgreen'
ns3_x = 155; ns3_y = 710; ns3_col = 'palegoldenrod'

# %%
reload(ebmBOX)

#(start, end, ftype, sdir, varname, fname, y, x)
pkldir = './pkls/'
start = '2017-01-01' #start of timeperiod
end = '2017-12-31' #end of timeperiod (typically a year)
ftype = 'carp' #type of model result .nc 
sdir = 'SHIFT/SHIFT_ncs/' #where under directory tree do we find ncs 
varname = 'dissolved_inorganic_carbon' #name of variable


fname = pkldir + 'SHIFT_DIC_means_cs2_BOX'
y = cs2_y; x = cs2_x
ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
fname = pkldir + 'SHIFT_DIC_means_cs_BOX'
y = cs_y; x = cs_x
ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
fname = pkldir + 'SHIFT_DIC_means_cs3_BOX'
y = cs3_y; x = cs3_x
ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
fname = pkldir + 'SHIFT_DIC_means_haro2_BOX'
y = haro2_y; x = haro2_x
ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
fname = pkldir + 'SHIFT_DIC_means_haro_BOX'
y = haro_y; x = haro_x
ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
fname = pkldir + 'SHIFT_DIC_means_haro3_BOX'
y = haro3_y; x = haro3_x
ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
fname = pkldir + 'SHIFT_DIC_means_jdf2_BOX'
y = jdf2_y; x = jdf2_x
ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
fname = pkldir + 'SHIFT_DIC_means_jdf_BOX'
y = jdf_y; x = jdf_x
ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
fname = pkldir + 'SHIFT_DIC_means_jdf3_BOX'
y = jdf3_y; x = jdf3_x
ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
fname = pkldir + 'SHIFT_DIC_means_ns2_BOX'
y = ns2_y; x = ns2_x
ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
fname = pkldir + 'SHIFT_DIC_means_ns_BOX'
y = ns_y; x = ns_x
ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
fname = pkldir + 'SHIFT_DIC_means_ns3_BOX'
y = ns3_y; x = ns3_x
ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
# Out:
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs//SalishSeaCast_1d_*carp*20170101-20170101.nc
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# done making nclen
# ./pkls/SHIFT_DIC_means_cs2_BOX
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170101_20170130_carp_T_20170101-20170101.nc
# shape of dataset is
# (1, 40, 898, 398)
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170131_20170301_carp_T_20170220-20170220.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170401_20170430_carp_T_20170411-20170411.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170531_20170629_carp_T_20170531-20170531.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170630_20170729_carp_T_20170720-20170720.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170829_20170927_carp_T_20170908-20170908.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171028_20171126_carp_T_20171028-20171028.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171127_20171231_carp_T_20171217-20171217.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs//SalishSeaCast_1d_*carp*20170101-20170101.nc
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# done making nclen
# ./pkls/SHIFT_DIC_means_cs_BOX
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170101_20170130_carp_T_20170101-20170101.nc
# shape of dataset is
# (1, 40, 898, 398)
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170131_20170301_carp_T_20170220-20170220.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170401_20170430_carp_T_20170411-20170411.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170531_20170629_carp_T_20170531-20170531.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170630_20170729_carp_T_20170720-20170720.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170829_20170927_carp_T_20170908-20170908.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171028_20171126_carp_T_20171028-20171028.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171127_20171231_carp_T_20171217-20171217.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs//SalishSeaCast_1d_*carp*20170101-20170101.nc
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# done making nclen
# ./pkls/SHIFT_DIC_means_cs3_BOX
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170101_20170130_carp_T_20170101-20170101.nc
# shape of dataset is
# (1, 40, 898, 398)
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170131_20170301_carp_T_20170220-20170220.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170401_20170430_carp_T_20170411-20170411.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170531_20170629_carp_T_20170531-20170531.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170630_20170729_carp_T_20170720-20170720.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170829_20170927_carp_T_20170908-20170908.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171028_20171126_carp_T_20171028-20171028.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171127_20171231_carp_T_20171217-20171217.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs//SalishSeaCast_1d_*carp*20170101-20170101.nc
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# done making nclen
# ./pkls/SHIFT_DIC_means_haro2_BOX
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170101_20170130_carp_T_20170101-20170101.nc
# shape of dataset is
# (1, 40, 898, 398)
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170131_20170301_carp_T_20170220-20170220.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170401_20170430_carp_T_20170411-20170411.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170531_20170629_carp_T_20170531-20170531.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170630_20170729_carp_T_20170720-20170720.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170829_20170927_carp_T_20170908-20170908.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171028_20171126_carp_T_20171028-20171028.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171127_20171231_carp_T_20171217-20171217.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs//SalishSeaCast_1d_*carp*20170101-20170101.nc
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# done making nclen
# ./pkls/SHIFT_DIC_means_haro_BOX
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170101_20170130_carp_T_20170101-20170101.nc
# shape of dataset is
# (1, 40, 898, 398)
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170131_20170301_carp_T_20170220-20170220.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170401_20170430_carp_T_20170411-20170411.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170531_20170629_carp_T_20170531-20170531.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170630_20170729_carp_T_20170720-20170720.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170829_20170927_carp_T_20170908-20170908.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171028_20171126_carp_T_20171028-20171028.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171127_20171231_carp_T_20171217-20171217.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs//SalishSeaCast_1d_*carp*20170101-20170101.nc
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# done making nclen
# ./pkls/SHIFT_DIC_means_haro3_BOX
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170101_20170130_carp_T_20170101-20170101.nc
# shape of dataset is
# (1, 40, 898, 398)
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170131_20170301_carp_T_20170220-20170220.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170401_20170430_carp_T_20170411-20170411.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170531_20170629_carp_T_20170531-20170531.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170630_20170729_carp_T_20170720-20170720.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170829_20170927_carp_T_20170908-20170908.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171028_20171126_carp_T_20171028-20171028.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171127_20171231_carp_T_20171217-20171217.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs//SalishSeaCast_1d_*carp*20170101-20170101.nc
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# done making nclen
# ./pkls/SHIFT_DIC_means_jdf2_BOX
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170101_20170130_carp_T_20170101-20170101.nc
# shape of dataset is
# (1, 40, 898, 398)
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170131_20170301_carp_T_20170220-20170220.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170401_20170430_carp_T_20170411-20170411.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170531_20170629_carp_T_20170531-20170531.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170630_20170729_carp_T_20170720-20170720.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170829_20170927_carp_T_20170908-20170908.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171028_20171126_carp_T_20171028-20171028.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171127_20171231_carp_T_20171217-20171217.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs//SalishSeaCast_1d_*carp*20170101-20170101.nc
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# done making nclen
# ./pkls/SHIFT_DIC_means_jdf_BOX
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170101_20170130_carp_T_20170101-20170101.nc
# shape of dataset is
# (1, 40, 898, 398)
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170131_20170301_carp_T_20170220-20170220.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170401_20170430_carp_T_20170411-20170411.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170531_20170629_carp_T_20170531-20170531.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170630_20170729_carp_T_20170720-20170720.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170829_20170927_carp_T_20170908-20170908.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171028_20171126_carp_T_20171028-20171028.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171127_20171231_carp_T_20171217-20171217.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs//SalishSeaCast_1d_*carp*20170101-20170101.nc
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# done making nclen
# ./pkls/SHIFT_DIC_means_jdf3_BOX
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170101_20170130_carp_T_20170101-20170101.nc
# shape of dataset is
# (1, 40, 898, 398)
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170131_20170301_carp_T_20170220-20170220.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170401_20170430_carp_T_20170411-20170411.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170531_20170629_carp_T_20170531-20170531.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170630_20170729_carp_T_20170720-20170720.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170829_20170927_carp_T_20170908-20170908.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171028_20171126_carp_T_20171028-20171028.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171127_20171231_carp_T_20171217-20171217.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs//SalishSeaCast_1d_*carp*20170101-20170101.nc
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# done making nclen
# ./pkls/SHIFT_DIC_means_ns2_BOX
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170101_20170130_carp_T_20170101-20170101.nc
# shape of dataset is
# (1, 40, 898, 398)
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170131_20170301_carp_T_20170220-20170220.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170401_20170430_carp_T_20170411-20170411.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170531_20170629_carp_T_20170531-20170531.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170630_20170729_carp_T_20170720-20170720.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170829_20170927_carp_T_20170908-20170908.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171028_20171126_carp_T_20171028-20171028.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171127_20171231_carp_T_20171217-20171217.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs//SalishSeaCast_1d_*carp*20170101-20170101.nc
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# done making nclen
# ./pkls/SHIFT_DIC_means_ns_BOX
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170101_20170130_carp_T_20170101-20170101.nc
# shape of dataset is
# (1, 40, 898, 398)
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170131_20170301_carp_T_20170220-20170220.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170401_20170430_carp_T_20170411-20170411.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170531_20170629_carp_T_20170531-20170531.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170630_20170729_carp_T_20170720-20170720.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170829_20170927_carp_T_20170908-20170908.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171028_20171126_carp_T_20171028-20171028.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171127_20171231_carp_T_20171217-20171217.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs//SalishSeaCast_1d_*carp*20170101-20170101.nc
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# done making nclen
# ./pkls/SHIFT_DIC_means_ns3_BOX
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170101_20170130_carp_T_20170101-20170101.nc
# shape of dataset is
# (1, 40, 898, 398)
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170131_20170301_carp_T_20170220-20170220.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170401_20170430_carp_T_20170411-20170411.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170531_20170629_carp_T_20170531-20170531.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170630_20170729_carp_T_20170720-20170720.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170829_20170927_carp_T_20170908-20170908.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171028_20171126_carp_T_20171028-20171028.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171127_20171231_carp_T_20171217-20171217.nc

# %%
#(start, end, ftype, sdir, varname, fname, y, x)
pkldir = './pkls/'

ftype = 'carp' #type of model result .nc 
sdir = 'SHIFT/SHIFT_ncs/' #where under directory tree do we find ncs 
varname = 'dissolved_inorganic_carbon' #name of variable
fname = pkldir + 'SHIFT_DIC_means_inletsIN'


ebm.extractor(start, end, ftype, sdir, varname, fname,  False)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# done making nclen
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170101_20170130_carp_T_20170101-20170101.nc
# shape of dataset is
# (1, 40, 898, 398)
# nansum(dataset) -checksum to make sure inlet mask works - false/true should give different answers
# 4315911000.0
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170131_20170301_carp_T_20170220-20170220.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170401_20170430_carp_T_20170411-20170411.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170531_20170629_carp_T_20170531-20170531.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170630_20170729_carp_T_20170720-20170720.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20170829_20170927_carp_T_20170908-20170908.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171028_20171126_carp_T_20171028-20171028.nc
# /data/tjarniko/results/RIV_PIL/SHIFT/SHIFT_ncs/SalishSeaCast_1d_20171127_20171231_carp_T_20171217-20171217.nc
