# %% [markdown]
# ## Task:
#
# Susan has created a daily climatology of watershed discharges, based on monthly means. SEE:
# https://github.com/SalishSeaCast/tools/blob/master/I_ForcingFiles/Rivers/SeasonalCyclesFromMonthlyMeans.ipynb
#
# Daily files read into the model are currently in the form:
#
#     "R201702DFraCElse_y2017m01d10.nc"
# stored in:
#
#     /results/forcing/rivers
# where the Fraser has a daily real-time value from the Hope gauge, and the rest of the rivers are the morison climatology.
#
# We need to create files of the above form, one file per day, except replacing the Morrison climatology with the interpolated climatology. Need to be v.v. careful with units, as m3/s units are not used in the model.
#
#     Rivers are treated like rain, added from above.  So kg of water/m2 /s where the m2 is horizontal area.  This we will call nf (nemo flux)
#     So for m3/s first we convert from mass to volume
#     nf / rho (fresh water so 1000 kg/m3)  so now we have m/s
#     Then multiply by the area of the grid cell
#      nf  / rho * e1t(i,j) *e2t(i,j)
#
# The steps are as follows:
#
#     1) Open the river climatology file from
#         rivers-climatology/watershed_climatologies/Salish_allrivers_daily.nc
#     2) use the river properties dictionary, the 'prop' key to distribute the climatology among individual rivers, still in m3/s, and save in a new dictionary -
#     3) translate from m3/s to kg/m2/s, save that into the new dictionary
#              ie eg river "nooksack" will have 365 numbers, in kg/m2/s
#     4) create new daily files and populate them with the numbers from 3, using the i and j values found in the river properties dictionary. These daily files are of a similar type as "R201702DFraCElse_y2017m01d10.nc"

# %%
# %reset
import netCDF4 as nc
import numpy as np
import arrow
import matplotlib.pyplot as plt

import sys
sys.path.append('/data/tjarniko/MEOPAR/tools/SalishSeaTools/salishsea_tools/')
#import mocsy
import river_201702 as rv
import river_downbyone2 as rv2
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# ### Trying to understand inconsistency between how rivers are seen in the different grids - using downbyone grid for the R201702DFraCElse_y2017m01d10.nc and other files...

# %%
sample_river_file = \
nc.Dataset('/results/forcing/rivers/R201702DFraCElse_y2015m07d25.nc')

#print(sample_river_file)

climatology_file = \
nc.Dataset('/data/tjarniko/MEOPAR/rivers-climatology/watershed_climatologies/Salish_allrivers_daily.nc')
#print(climatology_file['fraser'][300])

watersheds = ['howe', 'jdf', 'puget', 'skagit', 'fraser', \
              'evi_n', 'jervis', 'toba', 'bute', 'evi_s']

# %%
# import copy
# clim_dict = copy.deepcopy(rv.prop_dict)
# grid = nc.Dataset('/data/tjarniko/MEOPAR/grid/mesh_mask201702.nc')

# watersheds = ['howe', 'jdf', 'puget', 'skagit', 'fraser', \
#               'evi_n', 'jervis', 'toba', 'bute', 'evi_s']

# for w in watersheds:
#     interp_clim = climatology_file[w][:]

#     print(w)
#     #print(interp_clim)
#     rivers = (rv.prop_dict[w].keys())
#     for r in rivers:
#         #print(r)
#         prop_wshed = rv.prop_dict[w][r]['prop']
#         clim_dict[w][r]['interp_clim'] = prop_wshed * interp_clim
#         river_i = rv.prop_dict[w][r]['j']
#         river_j = rv.prop_dict[w][r]['i']
#         river_dj = rv.prop_dict[w][r]['di']
#         river_di = rv.prop_dict[w][r]['dj']
#         area = grid['e1t'][0,river_j,river_i]*grid['e2t'][0,river_j,river_i]
#         clim_dict[w][r]['interp_clim_modunits'] = prop_wshed * interp_clim / area * 1000
#        # if ((river_dj > 1) | (river_di > 1)):
#        #     print(r)
#        #     print(rv2.prop_dict[w][r])
# #runoff_m3 = (year_runoff / 1000) * t_area
# #runoff in model units = runoff_m3 / t_area * 1000

# %% [markdown]
# #### checking the Squamish river interpolated result against a daily file

# %% [markdown]
# #### checking the homathko river interpolated result against a daily file

# %%
# print(rv.prop_dict['bute'])


# riv_i = clim_dict['bute']['Homathko']['i']
# riv_j = clim_dict['bute']['Homathko']['j']
# riv_di = clim_dict['bute']['Homathko']['di']
# riv_dj = clim_dict['bute']['Homathko']['dj']
# print(riv_i)
# #print(sample_river_file['rorunoff'][0,532-2:532+2,385-2:385+2])
# print(sample_river_file['rorunoff'][0,riv_i:riv_i+riv_di,riv_j:riv_j+riv_dj])
# print(clim_dict['bute']['Homathko']['interp_clim_modunits'][219])

# %% [markdown]
# ###

# %% [markdown]
# #### THIS CODE CALCULATES THE APPROPRIATE DAILY CLIMATOLOGY FOR EACH RIVER, THEN (IF verbose == true) COMPARES IT FOR A SAMPLE DAY WITH THE MONTHLY CLIMATOLOGY FILE

# %%
# frasers = ['Fraser1','Fraser2','Fraser3','Fraser4']

# twit = 'Fraser1'

# twit not in frasers

# %% [markdown]
# ## rotate by 45 days forward

# %%
import copy
clim_dict = copy.deepcopy(rv.prop_dict)
grid = nc.Dataset('/data/tjarniko/MEOPAR/grid/mesh_mask201702.nc')

watersheds = ['howe', 'jdf', 'puget', 'skagit', 'fraser', \
              'evi_n', 'jervis', 'toba', 'bute', 'evi_s']

#print(np.shape(sample_river_file['rorunoff'][0,:,:]))
#print(np.max((sample_river_file['rorunoff'][0,:,:])))
verbose = False
frasers = ['Fraser']
for w in watersheds:
    interp_clim = climatology_file[w][:]
    #print('')
    print(w)
    #print(interp_clim)
    rivers = (rv.prop_dict[w].keys())
    for r in rivers:
        if (r not in frasers):

            prop_wshed = rv.prop_dict[w][r]['prop']
            clim_dict[w][r]['interp_clim'] = prop_wshed * interp_clim
            river_i = rv.prop_dict[w][r]['j']
            river_di = rv.prop_dict[w][r]['dj']

            river_j = rv.prop_dict[w][r]['i']
            river_dj = rv.prop_dict[w][r]['di']
            area = grid['e1t'][0,river_j,river_i]*grid['e2t'][0,river_j,river_i]
            clim_dict[w][r]['interp_clim_modunits'] = prop_wshed * interp_clim / area * 1000
            size_inflow = river_di * river_dj
            if verbose == True:
                print(r)
                print(size_inflow)
                print('sample river file runoff')
                print(sample_river_file['rorunoff'][0,river_j:river_j+river_dj,river_i:river_i+river_di])
                print(sample_river_file['rorunoff'][0,river_j-1:river_j+river_dj+1,river_i-1:river_i+river_di+1])
                print('daily climatology result: ' + str(clim_dict[w][r]['interp_clim_modunits'][219]))
                print('')
# Out:
# howe
# jdf
# puget
# skagit
# fraser
# evi_n
# jervis
# toba
# bute
# evi_s

# %%
sample_river_file = \
nc.Dataset('/results/forcing/rivers/R201702DFraCElse_y2015m07d25.nc')

#print(sample_river_file)

print(rv.prop_dict['howe'])


riv_i = clim_dict['howe']['Squamish']['i']
riv_j = clim_dict['howe']['Squamish']['j']
riv_di = clim_dict['howe']['Squamish']['di']
riv_dj = clim_dict['howe']['Squamish']['dj']
print(riv_i)
#print(sample_river_file['rorunoff'][0,532-2:532+2,385-2:385+2])
print(sample_river_file['rorunoff'][0,riv_i:riv_i+riv_di,riv_j:riv_j+riv_dj])
print(clim_dict['howe']['Squamish']['interp_clim_modunits'][219])

#(rivdat.variables['rorunoff'][8,534,384:386])
# Out:
# {'Squamish': {'prop': 0.9, 'i': 534, 'j': 384, 'di': 1, 'dj': 2, 'depth': 2}, 'Burrard': {'prop': 0.1, 'i': 457, 'j': 343, 'di': 3, 'dj': 1, 'depth': 3}}
# 534
# [[1.8686054 1.8686054]]
# 3.2455642

# %%
rivers = (rv.prop_dict['fraser'].keys())
print(rivers)

for r in rivers:
    print(r)
    print(rv.prop_dict['fraser'][r])
    
# print(rv.prop_dict)
# Out:
# dict_keys(['Dakota', 'Terrel', 'Nooksack', 'Squallum', 'Lakethingo', 'Chuckanut', 'Fraser'])
# Dakota
# {'prop': 0.00096, 'i': 363, 'j': 357, 'di': 1, 'dj': 1, 'depth': 1}
# Terrel
# {'prop': 0.00064, 'i': 353, 'j': 350, 'di': 1, 'dj': 1, 'depth': 1}
# Nooksack
# {'prop': 0.012, 'i': 312, 'j': 354, 'di': 1, 'dj': 4, 'depth': 1}
# Squallum
# {'prop': 0.0008, 'i': 305, 'j': 365, 'di': 1, 'dj': 1, 'depth': 1}
# Lakethingo
# {'prop': 0.00096, 'i': 302, 'j': 367, 'di': 1, 'dj': 1, 'depth': 1}
# Chuckanut
# {'prop': 0.00064, 'i': 298, 'j': 361, 'di': 1, 'dj': 1, 'depth': 1}
# Fraser
# {'prop': 0.984, 'i': 500, 'j': 394, 'di': 1, 'dj': 1, 'depth': 3}

# %%
start ='2017-01-01'
end ='2017-12-31'
frasers = ['Fraser']
verbose = False
start_run = arrow.get(start)
end_run = arrow.get(end)
wat_to_rot = ['skagit', 'howe', 'bute', 'toba']

import pickle
#pickle.dump(hydro_old_Fraser, open("hydroFraser_2017real.pkl", 'wb'))
hydroFraser_2017real = pickle.load(open('./hydroFraser_2017real.pkl', 'rb'))  

arrow_array = []

for r in arrow.Arrow.span_range('day', start_run, end_run):
    arrow_array.append(r)


for date in range(0,len(arrow_array)):
    print(date)
    #get appropriate date and open old river file
    tdate = arrow_array[date][0]
    y = tdate.format('YYYY')
    m = tdate.format('MM')
    d = tdate.format('DD')
    tday = f"y{y}m{m}d{d}"
    print(tday)
    trivfile = f"/results/forcing/rivers/R201702DFraCElse_y{y}m{m}d{d}.nc"
    triv = nc.Dataset(trivfile)
    #print(triv)
    
    ## open rorunoff file and copy it
    rorunoff = triv['rorunoff'][:]
    if verbose == True:
        print(np.shape(rorunoff))
    new_rorunoff = np.copy(rorunoff)
    
    #populate rorunoff with new climatology for ever river except the frasers
    for w in watersheds:
        #interp_clim = climatology_file[w][:]
        if verbose == True:
            print('')
            print(w)
        #print(interp_clim)
        rivers = (rv.prop_dict[w].keys())
        for r in rivers:
            if (r not in frasers):

                #prop_wshed = rv2.prop_dict[w][r]['prop']
                #clim_dict[w][r]['interp_clim'] = prop_wshed * interp_clim
                river_i = rv.prop_dict[w][r]['j']
                river_di = rv.prop_dict[w][r]['dj']

                river_j = rv.prop_dict[w][r]['i']
                river_dj = rv.prop_dict[w][r]['di']
                #area = grid['e1t'][0,river_j,river_i]*grid['e2t'][0,river_j,river_i]
                #clim_dict[w][r]['interp_clim_modunits'] = prop_wshed * interp_clim / area * 1000
                total_inflow = clim_dict[w][r]['interp_clim_modunits'][:]
                if w in wat_to_rot:
                    total_inflow = np.roll(total_inflow,-45)
                    
                todays_inflow = total_inflow[date]
                size_inflow = river_di * river_dj
                populate_inflow = todays_inflow/size_inflow
                new_rorunoff[0,river_j:river_j+river_dj,river_i:river_i+river_di] = populate_inflow
            
            if (r in frasers):

                #prop_wshed = rv2.prop_dict[w][r]['prop']
                #clim_dict[w][r]['interp_clim'] = prop_wshed * interp_clim
                river_i = rv.prop_dict[w][r]['j']
                river_di = rv.prop_dict[w][r]['dj']

                river_j = rv.prop_dict[w][r]['i']
                river_dj = rv.prop_dict[w][r]['di']
                #area = grid['e1t'][0,river_j,river_i]*grid['e2t'][0,river_j,river_i]
                #clim_dict[w][r]['interp_clim_modunits'] = prop_wshed * interp_clim / area * 1000
                total_inflow = hydroFraser_2017real
                total_inflow = np.roll(total_inflow,-45)
#                 if w in wat_to_rot:
#                     total_inflow = np.roll(total_inflow,-45)
                    
                todays_inflow = total_inflow[date]
                size_inflow = river_di * river_dj
                populate_inflow = todays_inflow/size_inflow
                new_rorunoff[0,river_j:river_j+river_dj,river_i:river_i+river_di] = populate_inflow                

            if verbose == True:
                print(r)
                print(size_inflow)
                print('daily climatology result: ' + str(clim_dict[w][r]['interp_clim_modunits'][date]))
                print('')


    
    ### code to copy the new rivers file into its own .nc
    dsin = triv
    newrivfile = f"./daily_45Dearly/R201702DFraDailyElse45Dearly_y{y}m{m}d{d}.nc"
    ncname = newrivfile
    print(newrivfile)
    
    dsout = nc.Dataset(ncname, "w", format="NETCDF4")
    #Copy dimensions
    for dname, the_dim in dsin.dimensions.items():
        #print(dname)
        #print(len(the_dim))
        dsout.createDimension(dname, len(the_dim) if not the_dim.isunlimited() else None)
    # Copy variables
    for v_name, varin in dsin.variables.items():
        #print(v_name)
        outVar = dsout.createVariable(v_name, varin.datatype, varin.dimensions)
        #print(varin.datatype)
        outVar.setncatts({k: varin.getncattr(k) for k in varin.ncattrs()})
        outVar[:] = varin[:]
    dsout['rorunoff'][:] = new_rorunoff
    dsout.close()
# Out:
# 0
# y2017m01d01
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d01.nc
# 1
# y2017m01d02
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d02.nc
# 2
# y2017m01d03
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d03.nc
# 3
# y2017m01d04
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d04.nc
# 4
# y2017m01d05
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d05.nc
# 5
# y2017m01d06
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d06.nc
# 6
# y2017m01d07
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d07.nc
# 7
# y2017m01d08
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d08.nc
# 8
# y2017m01d09
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d09.nc
# 9
# y2017m01d10
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d10.nc
# 10
# y2017m01d11
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d11.nc
# 11
# y2017m01d12
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d12.nc
# 12
# y2017m01d13
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d13.nc
# 13
# y2017m01d14
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d14.nc
# 14
# y2017m01d15
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d15.nc
# 15
# y2017m01d16
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d16.nc
# 16
# y2017m01d17
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d17.nc
# 17
# y2017m01d18
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d18.nc
# 18
# y2017m01d19
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d19.nc
# 19
# y2017m01d20
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d20.nc
# 20
# y2017m01d21
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d21.nc
# 21
# y2017m01d22
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d22.nc
# 22
# y2017m01d23
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d23.nc
# 23
# y2017m01d24
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d24.nc
# 24
# y2017m01d25
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d25.nc
# 25
# y2017m01d26
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d26.nc
# 26
# y2017m01d27
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d27.nc
# 27
# y2017m01d28
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d28.nc
# 28
# y2017m01d29
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d29.nc
# 29
# y2017m01d30
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d30.nc
# 30
# y2017m01d31
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m01d31.nc
# 31
# y2017m02d01
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d01.nc
# 32
# y2017m02d02
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d02.nc
# 33
# y2017m02d03
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d03.nc
# 34
# y2017m02d04
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d04.nc
# 35
# y2017m02d05
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d05.nc
# 36
# y2017m02d06
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d06.nc
# 37
# y2017m02d07
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d07.nc
# 38
# y2017m02d08
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d08.nc
# 39
# y2017m02d09
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d09.nc
# 40
# y2017m02d10
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d10.nc
# 41
# y2017m02d11
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d11.nc
# 42
# y2017m02d12
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d12.nc
# 43
# y2017m02d13
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d13.nc
# 44
# y2017m02d14
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d14.nc
# 45
# y2017m02d15
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d15.nc
# 46
# y2017m02d16
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d16.nc
# 47
# y2017m02d17
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d17.nc
# 48
# y2017m02d18
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d18.nc
# 49
# y2017m02d19
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d19.nc
# 50
# y2017m02d20
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d20.nc
# 51
# y2017m02d21
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d21.nc
# 52
# y2017m02d22
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d22.nc
# 53
# y2017m02d23
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d23.nc
# 54
# y2017m02d24
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d24.nc
# 55
# y2017m02d25
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d25.nc
# 56
# y2017m02d26
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d26.nc
# 57
# y2017m02d27
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d27.nc
# 58
# y2017m02d28
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m02d28.nc
# 59
# y2017m03d01
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d01.nc
# 60
# y2017m03d02
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d02.nc
# 61
# y2017m03d03
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d03.nc
# 62
# y2017m03d04
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d04.nc
# 63
# y2017m03d05
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d05.nc
# 64
# y2017m03d06
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d06.nc
# 65
# y2017m03d07
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d07.nc
# 66
# y2017m03d08
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d08.nc
# 67
# y2017m03d09
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d09.nc
# 68
# y2017m03d10
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d10.nc
# 69
# y2017m03d11
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d11.nc
# 70
# y2017m03d12
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d12.nc
# 71
# y2017m03d13
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d13.nc
# 72
# y2017m03d14
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d14.nc
# 73
# y2017m03d15
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d15.nc
# 74
# y2017m03d16
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d16.nc
# 75
# y2017m03d17
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d17.nc
# 76
# y2017m03d18
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d18.nc
# 77
# y2017m03d19
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d19.nc
# 78
# y2017m03d20
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d20.nc
# 79
# y2017m03d21
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d21.nc
# 80
# y2017m03d22
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d22.nc
# 81
# y2017m03d23
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d23.nc
# 82
# y2017m03d24
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d24.nc
# 83
# y2017m03d25
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d25.nc
# 84
# y2017m03d26
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d26.nc
# 85
# y2017m03d27
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d27.nc
# 86
# y2017m03d28
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d28.nc
# 87
# y2017m03d29
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d29.nc
# 88
# y2017m03d30
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d30.nc
# 89
# y2017m03d31
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m03d31.nc
# 90
# y2017m04d01
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d01.nc
# 91
# y2017m04d02
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d02.nc
# 92
# y2017m04d03
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d03.nc
# 93
# y2017m04d04
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d04.nc
# 94
# y2017m04d05
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d05.nc
# 95
# y2017m04d06
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d06.nc
# 96
# y2017m04d07
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d07.nc
# 97
# y2017m04d08
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d08.nc
# 98
# y2017m04d09
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d09.nc
# 99
# y2017m04d10
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d10.nc
# 100
# y2017m04d11
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d11.nc
# 101
# y2017m04d12
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d12.nc
# 102
# y2017m04d13
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d13.nc
# 103
# y2017m04d14
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d14.nc
# 104
# y2017m04d15
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d15.nc
# 105
# y2017m04d16
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d16.nc
# 106
# y2017m04d17
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d17.nc
# 107
# y2017m04d18
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d18.nc
# 108
# y2017m04d19
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d19.nc
# 109
# y2017m04d20
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d20.nc
# 110
# y2017m04d21
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d21.nc
# 111
# y2017m04d22
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d22.nc
# 112
# y2017m04d23
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d23.nc
# 113
# y2017m04d24
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d24.nc
# 114
# y2017m04d25
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d25.nc
# 115
# y2017m04d26
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d26.nc
# 116
# y2017m04d27
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d27.nc
# 117
# y2017m04d28
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d28.nc
# 118
# y2017m04d29
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d29.nc
# 119
# y2017m04d30
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m04d30.nc
# 120
# y2017m05d01
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d01.nc
# 121
# y2017m05d02
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d02.nc
# 122
# y2017m05d03
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d03.nc
# 123
# y2017m05d04
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d04.nc
# 124
# y2017m05d05
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d05.nc
# 125
# y2017m05d06
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d06.nc
# 126
# y2017m05d07
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d07.nc
# 127
# y2017m05d08
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d08.nc
# 128
# y2017m05d09
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d09.nc
# 129
# y2017m05d10
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d10.nc
# 130
# y2017m05d11
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d11.nc
# 131
# y2017m05d12
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d12.nc
# 132
# y2017m05d13
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d13.nc
# 133
# y2017m05d14
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d14.nc
# 134
# y2017m05d15
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d15.nc
# 135
# y2017m05d16
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d16.nc
# 136
# y2017m05d17
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d17.nc
# 137
# y2017m05d18
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d18.nc
# 138
# y2017m05d19
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d19.nc
# 139
# y2017m05d20
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d20.nc
# 140
# y2017m05d21
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d21.nc
# 141
# y2017m05d22
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d22.nc
# 142
# y2017m05d23
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d23.nc
# 143
# y2017m05d24
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d24.nc
# 144
# y2017m05d25
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d25.nc
# 145
# y2017m05d26
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d26.nc
# 146
# y2017m05d27
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d27.nc
# 147
# y2017m05d28
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d28.nc
# 148
# y2017m05d29
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d29.nc
# 149
# y2017m05d30
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d30.nc
# 150
# y2017m05d31
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m05d31.nc
# 151
# y2017m06d01
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d01.nc
# 152
# y2017m06d02
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d02.nc
# 153
# y2017m06d03
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d03.nc
# 154
# y2017m06d04
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d04.nc
# 155
# y2017m06d05
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d05.nc
# 156
# y2017m06d06
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d06.nc
# 157
# y2017m06d07
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d07.nc
# 158
# y2017m06d08
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d08.nc
# 159
# y2017m06d09
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d09.nc
# 160
# y2017m06d10
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d10.nc
# 161
# y2017m06d11
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d11.nc
# 162
# y2017m06d12
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d12.nc
# 163
# y2017m06d13
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d13.nc
# 164
# y2017m06d14
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d14.nc
# 165
# y2017m06d15
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d15.nc
# 166
# y2017m06d16
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d16.nc
# 167
# y2017m06d17
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d17.nc
# 168
# y2017m06d18
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d18.nc
# 169
# y2017m06d19
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d19.nc
# 170
# y2017m06d20
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d20.nc
# 171
# y2017m06d21
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d21.nc
# 172
# y2017m06d22
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d22.nc
# 173
# y2017m06d23
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d23.nc
# 174
# y2017m06d24
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d24.nc
# 175
# y2017m06d25
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d25.nc
# 176
# y2017m06d26
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d26.nc
# 177
# y2017m06d27
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d27.nc
# 178
# y2017m06d28
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d28.nc
# 179
# y2017m06d29
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d29.nc
# 180
# y2017m06d30
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m06d30.nc
# 181
# y2017m07d01
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d01.nc
# 182
# y2017m07d02
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d02.nc
# 183
# y2017m07d03
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d03.nc
# 184
# y2017m07d04
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d04.nc
# 185
# y2017m07d05
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d05.nc
# 186
# y2017m07d06
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d06.nc
# 187
# y2017m07d07
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d07.nc
# 188
# y2017m07d08
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d08.nc
# 189
# y2017m07d09
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d09.nc
# 190
# y2017m07d10
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d10.nc
# 191
# y2017m07d11
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d11.nc
# 192
# y2017m07d12
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d12.nc
# 193
# y2017m07d13
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d13.nc
# 194
# y2017m07d14
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d14.nc
# 195
# y2017m07d15
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d15.nc
# 196
# y2017m07d16
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d16.nc
# 197
# y2017m07d17
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d17.nc
# 198
# y2017m07d18
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d18.nc
# 199
# y2017m07d19
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d19.nc
# 200
# y2017m07d20
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d20.nc
# 201
# y2017m07d21
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d21.nc
# 202
# y2017m07d22
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d22.nc
# 203
# y2017m07d23
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d23.nc
# 204
# y2017m07d24
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d24.nc
# 205
# y2017m07d25
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d25.nc
# 206
# y2017m07d26
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d26.nc
# 207
# y2017m07d27
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d27.nc
# 208
# y2017m07d28
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d28.nc
# 209
# y2017m07d29
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d29.nc
# 210
# y2017m07d30
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d30.nc
# 211
# y2017m07d31
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m07d31.nc
# 212
# y2017m08d01
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d01.nc
# 213
# y2017m08d02
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d02.nc
# 214
# y2017m08d03
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d03.nc
# 215
# y2017m08d04
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d04.nc
# 216
# y2017m08d05
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d05.nc
# 217
# y2017m08d06
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d06.nc
# 218
# y2017m08d07
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d07.nc
# 219
# y2017m08d08
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d08.nc
# 220
# y2017m08d09
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d09.nc
# 221
# y2017m08d10
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d10.nc
# 222
# y2017m08d11
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d11.nc
# 223
# y2017m08d12
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d12.nc
# 224
# y2017m08d13
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d13.nc
# 225
# y2017m08d14
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d14.nc
# 226
# y2017m08d15
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d15.nc
# 227
# y2017m08d16
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d16.nc
# 228
# y2017m08d17
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d17.nc
# 229
# y2017m08d18
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d18.nc
# 230
# y2017m08d19
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d19.nc
# 231
# y2017m08d20
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d20.nc
# 232
# y2017m08d21
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d21.nc
# 233
# y2017m08d22
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d22.nc
# 234
# y2017m08d23
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d23.nc
# 235
# y2017m08d24
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d24.nc
# 236
# y2017m08d25
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d25.nc
# 237
# y2017m08d26
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d26.nc
# 238
# y2017m08d27
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d27.nc
# 239
# y2017m08d28
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d28.nc
# 240
# y2017m08d29
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d29.nc
# 241
# y2017m08d30
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d30.nc
# 242
# y2017m08d31
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m08d31.nc
# 243
# y2017m09d01
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d01.nc
# 244
# y2017m09d02
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d02.nc
# 245
# y2017m09d03
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d03.nc
# 246
# y2017m09d04
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d04.nc
# 247
# y2017m09d05
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d05.nc
# 248
# y2017m09d06
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d06.nc
# 249
# y2017m09d07
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d07.nc
# 250
# y2017m09d08
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d08.nc
# 251
# y2017m09d09
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d09.nc
# 252
# y2017m09d10
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d10.nc
# 253
# y2017m09d11
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d11.nc
# 254
# y2017m09d12
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d12.nc
# 255
# y2017m09d13
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d13.nc
# 256
# y2017m09d14
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d14.nc
# 257
# y2017m09d15
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d15.nc
# 258
# y2017m09d16
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d16.nc
# 259
# y2017m09d17
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d17.nc
# 260
# y2017m09d18
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d18.nc
# 261
# y2017m09d19
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d19.nc
# 262
# y2017m09d20
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d20.nc
# 263
# y2017m09d21
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d21.nc
# 264
# y2017m09d22
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d22.nc
# 265
# y2017m09d23
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d23.nc
# 266
# y2017m09d24
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d24.nc
# 267
# y2017m09d25
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d25.nc
# 268
# y2017m09d26
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d26.nc
# 269
# y2017m09d27
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d27.nc
# 270
# y2017m09d28
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d28.nc
# 271
# y2017m09d29
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d29.nc
# 272
# y2017m09d30
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m09d30.nc
# 273
# y2017m10d01
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d01.nc
# 274
# y2017m10d02
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d02.nc
# 275
# y2017m10d03
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d03.nc
# 276
# y2017m10d04
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d04.nc
# 277
# y2017m10d05
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d05.nc
# 278
# y2017m10d06
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d06.nc
# 279
# y2017m10d07
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d07.nc
# 280
# y2017m10d08
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d08.nc
# 281
# y2017m10d09
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d09.nc
# 282
# y2017m10d10
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d10.nc
# 283
# y2017m10d11
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d11.nc
# 284
# y2017m10d12
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d12.nc
# 285
# y2017m10d13
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d13.nc
# 286
# y2017m10d14
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d14.nc
# 287
# y2017m10d15
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d15.nc
# 288
# y2017m10d16
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d16.nc
# 289
# y2017m10d17
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d17.nc
# 290
# y2017m10d18
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d18.nc
# 291
# y2017m10d19
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d19.nc
# 292
# y2017m10d20
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d20.nc
# 293
# y2017m10d21
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d21.nc
# 294
# y2017m10d22
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d22.nc
# 295
# y2017m10d23
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d23.nc
# 296
# y2017m10d24
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d24.nc
# 297
# y2017m10d25
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d25.nc
# 298
# y2017m10d26
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d26.nc
# 299
# y2017m10d27
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d27.nc
# 300
# y2017m10d28
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d28.nc
# 301
# y2017m10d29
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d29.nc
# 302
# y2017m10d30
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d30.nc
# 303
# y2017m10d31
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m10d31.nc
# 304
# y2017m11d01
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d01.nc
# 305
# y2017m11d02
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d02.nc
# 306
# y2017m11d03
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d03.nc
# 307
# y2017m11d04
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d04.nc
# 308
# y2017m11d05
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d05.nc
# 309
# y2017m11d06
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d06.nc
# 310
# y2017m11d07
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d07.nc
# 311
# y2017m11d08
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d08.nc
# 312
# y2017m11d09
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d09.nc
# 313
# y2017m11d10
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d10.nc
# 314
# y2017m11d11
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d11.nc
# 315
# y2017m11d12
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d12.nc
# 316
# y2017m11d13
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d13.nc
# 317
# y2017m11d14
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d14.nc
# 318
# y2017m11d15
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d15.nc
# 319
# y2017m11d16
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d16.nc
# 320
# y2017m11d17
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d17.nc
# 321
# y2017m11d18
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d18.nc
# 322
# y2017m11d19
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d19.nc
# 323
# y2017m11d20
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d20.nc
# 324
# y2017m11d21
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d21.nc
# 325
# y2017m11d22
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d22.nc
# 326
# y2017m11d23
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d23.nc
# 327
# y2017m11d24
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d24.nc
# 328
# y2017m11d25
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d25.nc
# 329
# y2017m11d26
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d26.nc
# 330
# y2017m11d27
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d27.nc
# 331
# y2017m11d28
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d28.nc
# 332
# y2017m11d29
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d29.nc
# 333
# y2017m11d30
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m11d30.nc
# 334
# y2017m12d01
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d01.nc
# 335
# y2017m12d02
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d02.nc
# 336
# y2017m12d03
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d03.nc
# 337
# y2017m12d04
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d04.nc
# 338
# y2017m12d05
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d05.nc
# 339
# y2017m12d06
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d06.nc
# 340
# y2017m12d07
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d07.nc
# 341
# y2017m12d08
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d08.nc
# 342
# y2017m12d09
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d09.nc
# 343
# y2017m12d10
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d10.nc
# 344
# y2017m12d11
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d11.nc
# 345
# y2017m12d12
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d12.nc
# 346
# y2017m12d13
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d13.nc
# 347
# y2017m12d14
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d14.nc
# 348
# y2017m12d15
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d15.nc
# 349
# y2017m12d16
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d16.nc
# 350
# y2017m12d17
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d17.nc
# 351
# y2017m12d18
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d18.nc
# 352
# y2017m12d19
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d19.nc
# 353
# y2017m12d20
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d20.nc
# 354
# y2017m12d21
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d21.nc
# 355
# y2017m12d22
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d22.nc
# 356
# y2017m12d23
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d23.nc
# 357
# y2017m12d24
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d24.nc
# 358
# y2017m12d25
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d25.nc
# 359
# y2017m12d26
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d26.nc
# 360
# y2017m12d27
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d27.nc
# 361
# y2017m12d28
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d28.nc
# 362
# y2017m12d29
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d29.nc
# 363
# y2017m12d30
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d30.nc
# 364
# y2017m12d31
# ./daily_45Dearly/R201702DFraDailyElse45Dearly_y2017m12d31.nc

# %% [markdown]
# ### Check that the river daily files are populated exactly where the old ones were

# %%
new_rivfile = nc.Dataset(f"./daily_45Dearly/R201702DFraDailyElse45Dearly_y{y}m{m}d{d}.nc")
old_rivfile = nc.Dataset(f"/results/forcing/rivers/R201702DFraCElse_y{y}m{m}d{d}.nc")

new_runoff = new_rivfile['rorunoff'][:]
old_runoff = old_rivfile['rorunoff'][:]

populated_new = np.where(new_runoff != 0)
print(np.shape(populated_new))

populated_old = np.where(old_runoff != 0)
print(np.shape(populated_old))

pn = np.array(populated_new)
po = np.array(populated_old)
print(pn == po)

# comparison = populated_new == populated_old
# equal_arrays = comparison.all()
# print(equal_arrays)

# an_array = np.array([[1,2],[3,4]])
# another_array = np.array([[1,2],[3,4]])

# comparison = populated_old == another_array
# equal_arrays = comparison.all()
# print(equal_arrays)

# def cmpT(t1, t2): 
#   return sorted(t1) == sorted(t2)

# cmpT(populated_old,populated_new)
# Out:
# (3, 182)
# (3, 182)
# [[ True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True]
#  [ True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True]
#  [ True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True  True  True  True  True
#    True  True]]

# %%
type(populated_old)
# Out:
# tuple

# %%
def compare_hydrographs_for_a_given_river(wshed, river):
    
    w = wshed
    r = river
    
    hydro_old = np.zeros(365)
    hydro_new = np.zeros(365)
    
    river_i = rv.prop_dict[w][r]['j']
    river_di = rv.prop_dict[w][r]['dj']
    river_j = rv.prop_dict[w][r]['i']
    river_dj = rv.prop_dict[w][r]['di']

    start ='2017-01-01'
    end ='2017-12-31'
    
    verbose = False
    start_run = arrow.get(start)
    end_run = arrow.get(end)
    arrow_array = []

    for r in arrow.Arrow.span_range('day', start_run, end_run):
        arrow_array.append(r)
        
    for date in range(0,len(arrow_array)):
        #print(date)
        #get appropriate date and open old river file
        tdate = arrow_array[date][0]
        y = tdate.format('YYYY')
        m = tdate.format('MM')
        d = tdate.format('DD')
        tday = f"y{y}m{m}d{d}"
        #print(tday)
        trivfile = f"/results/forcing/rivers/R201702DFraCElse_y{y}m{m}d{d}.nc"
        triv = nc.Dataset(trivfile)
        newrivfile = f"./daily_45Dearly//R201702DFraDailyElse45Dearly_y{y}m{m}d{d}.nc"
        newriv = nc.Dataset(newrivfile)
        
        hydro_old[date] = np.sum(triv['rorunoff'][0,river_j:river_j+river_dj,river_i:river_i+river_di])
        hydro_new[date] = np.sum(newriv['rorunoff'][0,river_j:river_j+river_dj,river_i:river_i+river_di])
    
    return hydro_old, hydro_new

# %%
hydro_old_Squamish, hydro_new_Squamish = \
compare_hydrographs_for_a_given_river('howe', 'Squamish')
hydro_old_Homathko, hydro_new_Homathko = \
compare_hydrographs_for_a_given_river('bute', 'Homathko')
hydro_old_Powell, hydro_new_Powell = \
compare_hydrographs_for_a_given_river('jervis', 'Powell')
hydro_old_Toba, hydro_new_Toba = \
compare_hydrographs_for_a_given_river('toba', 'Toba')
hydro_old_Englishman, hydro_new_Englishman = \
compare_hydrographs_for_a_given_river('evi_s', 'Englishman')
hydro_old_SanJuan, hydro_new_SanJuan = \
compare_hydrographs_for_a_given_river('jdf', 'SanJuan')
hydro_old_Fraser, hydro_new_Fraser = \
compare_hydrographs_for_a_given_river('fraser', 'Fraser')

# %%
np.shape(hydro_old_Squamish)
# Out:
# (365,)

# %%
hydro_old_Squamish[364]

fig, ax = plt.subplots(1, 1, figsize=(10, 5))

ax.plot(np.arange(0,365,1),hydro_old_Squamish, \
        color = 'r', linestyle = ':',label = 'Squamish old')
ax.plot(np.arange(0,365,1),hydro_new_Squamish, \
        color = 'r', linestyle = '-',label = 'Squamish new')
ax.plot(np.arange(0,365,1),hydro_old_Homathko, \
        color = 'b', linestyle = ':',label = 'Homathko old')
ax.plot(np.arange(0,365,1),hydro_new_Homathko, \
        color = 'b', linestyle = '-',label = 'Homathko new')
ax.plot(np.arange(0,365,1),hydro_old_Powell, \
        color = 'mediumseagreen', linestyle = ':',label = 'Powell old')
ax.plot(np.arange(0,365,1),hydro_new_Powell, \
        color = 'mediumseagreen', linestyle = '-',label = 'Powell new')
ax.plot(np.arange(0,365,1),hydro_old_Toba, \
        color = 'saddlebrown', linestyle = ':',label = 'Toba old')
ax.plot(np.arange(0,365,1),hydro_new_Toba, \
        color = 'saddlebrown', linestyle = '-',label = 'Toba new')
ax.plot(np.arange(0,365,1),hydro_old_Englishman, \
        color = 'olivedrab', linestyle = ':',label = 'Englishman old')
ax.plot(np.arange(0,365,1),hydro_new_Englishman, \
        color = 'olivedrab', linestyle = '-',label = 'Englishman new')
ax.plot(np.arange(0,365,1),hydro_old_SanJuan, \
        color = 'orange', linestyle = ':',label = 'SanJuan old')
ax.plot(np.arange(0,365,1),hydro_new_SanJuan, \
        color = 'orange', linestyle = '-',label = 'SanJuan new')
ax.set_ylabel('discharge model units')
plt.legend(bbox_to_anchor = [1, 1])
# Out:
# 110.4358280915767
# 111.6039936542511

# %%
hydro_old_Fraser, hydro_new_Fraser = \
compare_hydrographs_for_a_given_river('fraser', 'Fraser')

fig, ax = plt.subplots(1, 1, figsize=(10, 5))

ax.plot(np.arange(0,365,1),hydro_old_Fraser, \
        color = 'r', linestyle = ':',label = 'Fraser old')
ax.plot(np.arange(0,365,1),hydro_new_Fraser, \
        color = 'r', linestyle = '-',label = 'Fraser new')
