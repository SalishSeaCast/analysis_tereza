# %% [markdown]
# ## EXTRA_CARBON

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Mythical code button"></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Mythical code button"></form>

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
plt.style.use('classic')
from matplotlib.patches import Rectangle
import pickle
from cmocean import cm
import warnings
import netCDF4 as nc
import arrow
import glob
import sys
#sys.path.append('../pyscripts/bylayer_extract/')
import extract_bylayer_mean_BOXMASK as ebmBOX 
import extract_bylayer_mean as ebm
from importlib import reload
from salishsea_tools import viz_tools

# %matplotlib inline
warnings.simplefilter('ignore')

plt.rcParams.update({'font.size': 13,
                     'xtick.labelsize' : 13,
                     'ytick.labelsize' : 13})

# %% [markdown]
# ### [A] Map definition and station definition

# %%
jdf_x = 85; jdf_y = 325; jdf_col = 'teal'
jdf2_x = 50; jdf2_y = 370; jdf2_col = 'mediumaquamarine'
jdf3_x = 130; jdf3_y = 290; jdf3_col = 'lightseagreen'

cs_x = 250; cs_y = 500; cs_col = 'royalblue'
cs2_x = 280; cs2_y = 440; cs2_col = 'navy'
cs3_x = 220; cs3_y = 540; cs3_col = 'dodgerblue'

haro_x = 230; haro_y = 310; haro_col = 'tomato'
haro2_x = 340; haro2_y = 290; haro2_col = 'firebrick'
haro3_x = 260; haro3_y = 335; haro3_col = 'indianred'


ns_x = 160; ns_y = 680; ns_col = 'olive'
ns2_x = 150; ns2_y = 640; ns2_col = 'yellowgreen'
ns3_x = 155; ns3_y = 710; ns3_col = 'palegoldenrod'

ps_x = 250; ps_y = 110; ps_col = 'magenta'
ps2_x = 260; ps2_y = 190; ps2_col = 'darkviolet'
# ps2_x = 
w = nc.Dataset('/data/tjarniko/results/hindcast.201905_dayavg_OmA-pH-pCO2/OmA_plus_20070104.nc')
pco2 = w['model_output']['pCO2'][:]
pco2[pco2>2e5] = np.nan
pco2[pco2<2000] = 500
fact = 1.5
fig = plt.figure(figsize=(12*fact,6.5*fact))

ax0 = fig.add_subplot(1,2,1)
#toba and bute

im = ax0.pcolormesh(pco2, cmap=cm.balance_r, vmin = 0, vmax = 800)
viz_tools.set_aspect(ax0)
#jdf
rect_jdf = Rectangle((jdf_x-10,jdf_y-10),20,20,linewidth=2,edgecolor=jdf_col,facecolor=jdf_col)
ax0.add_patch(rect_jdf)
rect_jdf = Rectangle((jdf2_x-10,jdf2_y-10),20,20,linewidth=2,edgecolor=jdf2_col,facecolor=jdf2_col)
ax0.add_patch(rect_jdf)
rect_jdf = Rectangle((jdf3_x-10,jdf3_y-10),20,20,linewidth=2,edgecolor=jdf3_col,facecolor=jdf3_col)
ax0.add_patch(rect_jdf)

rect_haro = Rectangle((haro_x-10,haro_y-10),20,20,linewidth=2,edgecolor=haro_col,facecolor=haro_col)
ax0.add_patch(rect_haro)
rect_haro = Rectangle((haro2_x-10,haro2_y-10),20,20,linewidth=2,edgecolor=haro2_col,facecolor=haro2_col)
ax0.add_patch(rect_haro)
rect_haro = Rectangle((haro3_x-10,haro3_y-10),20,20,linewidth=2,edgecolor=haro3_col,facecolor=haro3_col)
ax0.add_patch(rect_haro)

rect_cs = Rectangle((cs_x-10,cs_y-10),20,20,linewidth=2,edgecolor=cs_col,facecolor=cs_col)
ax0.add_patch(rect_cs)
rect_cs = Rectangle((cs2_x-10,cs2_y-10),20,20,linewidth=2,edgecolor=cs2_col,facecolor=cs2_col)
ax0.add_patch(rect_cs)
rect_cs = Rectangle((cs3_x-10,cs3_y-10),20,20,linewidth=2,edgecolor=cs3_col,facecolor=cs3_col)
ax0.add_patch(rect_cs)

rect_ns = Rectangle((ns_x-10,ns_y-10),20,20,linewidth=2,edgecolor=ns_col,facecolor=ns_col)
ax0.add_patch(rect_ns)
rect_ns = Rectangle((ns2_x-10,ns2_y-10),20,20,linewidth=2,edgecolor=ns2_col,facecolor=ns2_col)
ax0.add_patch(rect_ns)
rect_ns = Rectangle((ns3_x-10,ns3_y-10),20,20,linewidth=2,edgecolor=ns3_col,facecolor=ns3_col)
ax0.add_patch(rect_ns)

rect_ps = Rectangle((ps_x-10,ps_y-10),20,20,linewidth=2,edgecolor=ps_col,facecolor=ps_col)
ax0.add_patch(rect_ps)
rect_ps = Rectangle((ps2_x-10,ps2_y-10),20,20,linewidth=2,edgecolor=ps2_col,facecolor=ps2_col)
ax0.add_patch(rect_ps)


ax0.set_title('individual stations')
# Out:
# Text(0.5, 1.0, 'individual stations')

# %% [markdown]
# reload(ebmBOX)
#
#     # reload(ebmBOX)
#
#     # #(start, end, ftype, sdir, varname, fname, y, x)
#     # pkldir = '/data/tjarniko/MEOPAR/analysis_tereza/notebooks/PI_CARBON_PAPER/MAIN_ANALYSIS/pkls/'
#     # start = '2015-01-01' #start of timeperiod
#     # end = '2015-12-31' #end of timeperiod (typically a year)
#     # ftype = 'carp' #type of model result .nc
#     # sdir = 'MAIN/BR_3rd_2015' #where under directory tree do we find ncs
#     # varname = 'dissolved_inorganic_carbon' #name of variable
#     # fname = pkldir + 'BR3_DIC_means_cs2_BOX'
#     # y = cs2_y; x = cs2_x
#     # ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
#
# run for PI4, BR3 for the above 12 stations, usage case above

# %%
## 
reload(ebm)

#(start, end, ftype, sdir, varname, fname, y, x)
pkldir = './pkls/'
start = '2017-01-01' #start of timeperiod
end = '2017-12-31' #end of timeperiod (typically a year)
ftype = 'carp' #type of model result .nc 

# sdir = 'CAR50/' #where under directory tree do we find nps 
# varname = 'dissolved_inorganic_carbon' #name of variable
# fname = pkldir + 'CAR50_DIC_means_fullyear'
# ebm.extractor(start, end, ftype, sdir, varname, fname)


# sdir = 'NEWBUDGET/' #where under directory tree do we find nps 
# varname = 'dissolved_inorganic_carbon' #name of variable
# fname = pkldir + 'NEWBUDGET_DIC_means_fullyear'
# ebm.extractor(start, end, ftype, sdir, varname, fname)

# sdir = 'CAR50_2/' #where under directory tree do we find nps 
# varname = 'dissolved_inorganic_carbon' #name of variable
# fname = pkldir + 'CAR50_2_DIC_means_fullyear'
# ebm.extractor(start, end, ftype, sdir, varname, fname)

sdir = 'CAR50_4/' #where under directory tree do we find nps 
varname = 'dissolved_inorganic_carbon' #name of variable
fname = pkldir + 'CAR50_4_DIC_means_fullyear'
ebm.extractor(start, end, ftype, sdir, varname, fname)
# Out:
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170101-20170101.nc
# 0
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170102-20170102.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170103-20170103.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170104-20170104.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170105-20170105.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170106-20170106.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170107-20170107.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170108-20170108.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170109-20170109.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170110-20170110.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170111-20170111.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170112-20170112.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170113-20170113.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170114-20170114.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170115-20170115.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170116-20170116.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170117-20170117.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170118-20170118.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170119-20170119.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170120-20170120.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170121-20170121.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170122-20170122.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170123-20170123.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170124-20170124.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170125-20170125.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170126-20170126.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170127-20170127.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170128-20170128.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170129-20170129.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01jan17_RIVTA5/SalishSeaCast_1d_20170101_20170130_carp_T_20170130-20170130.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170131-20170131.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170201-20170201.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170202-20170202.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170203-20170203.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170204-20170204.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170205-20170205.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170206-20170206.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170207-20170207.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170208-20170208.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170209-20170209.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170210-20170210.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170211-20170211.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170212-20170212.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170213-20170213.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170214-20170214.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170215-20170215.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170216-20170216.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170217-20170217.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170218-20170218.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170219-20170219.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170220-20170220.nc
# 50
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170221-20170221.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170222-20170222.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170223-20170223.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170224-20170224.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170225-20170225.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170226-20170226.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170227-20170227.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170228-20170228.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31jan17_RIVTA5/SalishSeaCast_1d_20170131_20170301_carp_T_20170301-20170301.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170302-20170302.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170303-20170303.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170304-20170304.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170305-20170305.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170306-20170306.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170307-20170307.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170308-20170308.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170309-20170309.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170310-20170310.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170311-20170311.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170312-20170312.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170313-20170313.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170314-20170314.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170315-20170315.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170316-20170316.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170317-20170317.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170318-20170318.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170319-20170319.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170320-20170320.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170321-20170321.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170322-20170322.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170323-20170323.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170324-20170324.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170325-20170325.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170326-20170326.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170327-20170327.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170328-20170328.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170329-20170329.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170330-20170330.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/02mar17_RIVTA5/SalishSeaCast_1d_20170302_20170331_carp_T_20170331-20170331.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170401-20170401.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170402-20170402.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170403-20170403.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170404-20170404.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170405-20170405.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170406-20170406.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170407-20170407.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170408-20170408.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170409-20170409.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170410-20170410.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170411-20170411.nc
# 100
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170412-20170412.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170413-20170413.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170414-20170414.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170415-20170415.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170416-20170416.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170417-20170417.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170418-20170418.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170419-20170419.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170420-20170420.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170421-20170421.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170422-20170422.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170423-20170423.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170424-20170424.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170425-20170425.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170426-20170426.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170427-20170427.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170428-20170428.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170429-20170429.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01apr17_RIVTA5/SalishSeaCast_1d_20170401_20170430_carp_T_20170430-20170430.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170501-20170501.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170502-20170502.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170503-20170503.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170504-20170504.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170505-20170505.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170506-20170506.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170507-20170507.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170508-20170508.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170509-20170509.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170510-20170510.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170511-20170511.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170512-20170512.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170513-20170513.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170514-20170514.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170515-20170515.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170516-20170516.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170517-20170517.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170518-20170518.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170519-20170519.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170520-20170520.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170521-20170521.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170522-20170522.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170523-20170523.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170524-20170524.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170525-20170525.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170526-20170526.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170527-20170527.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170528-20170528.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170529-20170529.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/01may17_RIVTA5/SalishSeaCast_1d_20170501_20170530_carp_T_20170530-20170530.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170531-20170531.nc
# 150
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170601-20170601.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170602-20170602.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170603-20170603.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170604-20170604.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170605-20170605.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170606-20170606.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170607-20170607.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170608-20170608.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170609-20170609.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170610-20170610.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170611-20170611.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170612-20170612.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170613-20170613.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170614-20170614.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170615-20170615.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170616-20170616.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170617-20170617.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170618-20170618.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170619-20170619.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170620-20170620.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170621-20170621.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170622-20170622.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170623-20170623.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170624-20170624.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170625-20170625.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170626-20170626.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170627-20170627.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170628-20170628.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/31may17_RIVTA5/SalishSeaCast_1d_20170531_20170629_carp_T_20170629-20170629.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170630-20170630.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170701-20170701.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170702-20170702.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170703-20170703.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170704-20170704.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170705-20170705.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170706-20170706.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170707-20170707.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170708-20170708.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170709-20170709.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170710-20170710.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170711-20170711.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170712-20170712.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170713-20170713.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170714-20170714.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170715-20170715.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170716-20170716.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170717-20170717.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170718-20170718.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170719-20170719.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170720-20170720.nc
# 200
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170721-20170721.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170722-20170722.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170723-20170723.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170724-20170724.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170725-20170725.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170726-20170726.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170727-20170727.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170728-20170728.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jun17_RIVTA5/SalishSeaCast_1d_20170630_20170729_carp_T_20170729-20170729.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170730-20170730.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170731-20170731.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170801-20170801.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170802-20170802.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170803-20170803.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170804-20170804.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170805-20170805.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170806-20170806.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170807-20170807.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170808-20170808.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170809-20170809.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170810-20170810.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170811-20170811.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170812-20170812.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170813-20170813.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170814-20170814.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170815-20170815.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170816-20170816.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170817-20170817.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170818-20170818.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170819-20170819.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170820-20170820.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170821-20170821.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170822-20170822.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170823-20170823.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170824-20170824.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170825-20170825.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170826-20170826.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170827-20170827.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/30jul17_RIVTA5/SalishSeaCast_1d_20170730_20170828_carp_T_20170828-20170828.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170829-20170829.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170830-20170830.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170831-20170831.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170901-20170901.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170902-20170902.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170903-20170903.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170904-20170904.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170905-20170905.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170906-20170906.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170907-20170907.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170908-20170908.nc
# 250
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170909-20170909.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170910-20170910.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170911-20170911.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170912-20170912.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170913-20170913.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170914-20170914.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170915-20170915.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170916-20170916.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170917-20170917.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170918-20170918.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170919-20170919.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170920-20170920.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170921-20170921.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170922-20170922.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170923-20170923.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170924-20170924.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170925-20170925.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170926-20170926.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/29aug17_RIVTA5/SalishSeaCast_1d_20170829_20170927_carp_T_20170927-20170927.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20170928-20170928.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20170929-20170929.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20170930-20170930.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171001-20171001.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171002-20171002.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171003-20171003.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171004-20171004.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171005-20171005.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171006-20171006.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171007-20171007.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171008-20171008.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171009-20171009.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171010-20171010.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171011-20171011.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171012-20171012.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171013-20171013.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171014-20171014.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171015-20171015.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171016-20171016.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171017-20171017.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171018-20171018.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171019-20171019.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171020-20171020.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171021-20171021.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171022-20171022.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171023-20171023.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171024-20171024.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171025-20171025.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171026-20171026.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28sep17_RIVTA5/SalishSeaCast_1d_20170928_20171027_carp_T_20171027-20171027.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171028-20171028.nc
# 300
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171029-20171029.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171030-20171030.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171031-20171031.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171101-20171101.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171102-20171102.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171103-20171103.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171104-20171104.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171105-20171105.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171106-20171106.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171107-20171107.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171108-20171108.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171109-20171109.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171110-20171110.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171111-20171111.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171112-20171112.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171113-20171113.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171114-20171114.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171115-20171115.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171116-20171116.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171117-20171117.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171118-20171118.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171119-20171119.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171120-20171120.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171121-20171121.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171122-20171122.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171123-20171123.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171124-20171124.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171125-20171125.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/28oct17_RIVTA5/SalishSeaCast_1d_20171028_20171126_carp_T_20171126-20171126.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171127-20171127.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171128-20171128.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171129-20171129.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171130-20171130.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171201-20171201.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171202-20171202.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171203-20171203.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171204-20171204.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171205-20171205.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171206-20171206.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171207-20171207.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171208-20171208.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171209-20171209.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171210-20171210.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171211-20171211.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171212-20171212.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171213-20171213.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171214-20171214.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171215-20171215.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171216-20171216.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171217-20171217.nc
# 350
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171218-20171218.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171219-20171219.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171220-20171220.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171221-20171221.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171222-20171222.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171223-20171223.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171224-20171224.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171225-20171225.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27nov17_RIVTA5/SalishSeaCast_1d_20171127_20171226_carp_T_20171226-20171226.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27dec17_RIVTA5/SalishSeaCast_1d_20171227_20171231_carp_T_20171227-20171227.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27dec17_RIVTA5/SalishSeaCast_1d_20171227_20171231_carp_T_20171228-20171228.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27dec17_RIVTA5/SalishSeaCast_1d_20171227_20171231_carp_T_20171229-20171229.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27dec17_RIVTA5/SalishSeaCast_1d_20171227_20171231_carp_T_20171230-20171230.nc
# /data/tjarniko/results/FUTURE_runs/CAR50_4/27dec17_RIVTA5/SalishSeaCast_1d_20171227_20171231_carp_T_20171231-20171231.nc
# done making nclen
# 0
# nansum(dataset) -checksum to make sure inlet mask works - false/true should give different answers
# 4321642500.0
# 60
# 120
# 180
# 240
# 300
# 360

# %%
# ## 
# reload(ebm)

# #(start, end, ftype, sdir, varname, fname, y, x)
# pkldir = './pkls/'
# start = '2017-01-01' #start of timeperiod
# end = '2017-04-30' #end of timeperiod (typically a year)
# ftype = 'carp' #type of model result .nc

# %%
NB_DIC_to30apr = pickle.load(open('./pkls/NEWBUDGET_DIC_means_fullyear.pkl', 'rb')) 
C50_DIC_to30apr = pickle.load(open('./pkls/CAR50_DIC_means_fullyear.pkl', 'rb')) 
C50_2_DIC_to30apr = pickle.load(open('./pkls/CAR50_2_DIC_means_fullyear.pkl', 'rb')) 
C50_3_DIC_to30apr = pickle.load(open('./pkls/CAR50_3_DIC_means_fullyear.pkl', 'rb')) 
C50_4_DIC_to30apr = pickle.load(open('./pkls/CAR50_4_DIC_means_fullyear.pkl', 'rb')) 
# print(np.shape(NB_DIC_to30apr))

# print(NB_DIC_to30apr[:,90])

#getting depths
w = nc.Dataset('/data/tjarniko/MEOPAR/grid/mesh_mask201702.nc')
depth = (w['gdept_1d'][0,:])

tcm = cm.phase


fact = 0.5
fig, axs = plt.subplots(1,4, figsize=(26*fact, 14*fact), facecolor='w', edgecolor='k')
axs = axs.ravel()

for i in range(0,12):
    print(np.nanmean(C50_DIC_to30apr[:,i*30])-np.nanmean(NB_DIC_to30apr[:,i*30]))
    axs[0].plot(NB_DIC_to30apr[:,i*30], depth, color = tcm((i)/12),linestyle = '-', label = f'month {i}')
    axs[1].plot(C50_DIC_to30apr[:,i*30]-NB_DIC_to30apr[:,i*30], \
                depth, color = tcm((i)/12),linestyle = '-', label = f'month {i}')
    axs[2].plot(C50_3_DIC_to30apr[:,i*30]-C50_2_DIC_to30apr[:,i*30], \
                depth, color = tcm((i)/12),linestyle = '-', label = f'month {i}')
    axs[3].plot(C50_4_DIC_to30apr[:,i*30]-C50_3_DIC_to30apr[:,i*30], \
                depth, color = tcm((i)/12),linestyle = '-', label = f'month {i}')
# axs[0].invert_yaxis()
# axs[0].set_xlim([1700,2200])
# axs[0].grid()
# axs[0].legend(loc = 'best', fontsize = 10)
# axs[0].set_title('domain-wide DIC mean \n base run')
# axs[1].set_title('CAR50_1-BASE DIC \n increase by month')
# axs[1].invert_yaxis()
# axs[1].set_xlim([-5,30])
# axs[1].grid()

axs[0].set_xlim([1700,2200])
axs[1].set_xlim([-5,30])
axs[0].legend(loc = 'best', fontsize = 10)

axs[0].set_title('domain-wide DIC mean \n base run')
axs[1].set_title('CAR50_1-BASE DIC \n increase by month')
axs[2].set_title('CAR50_3-CAR50_2 \n increase by month')
axs[3].set_title('CAR50_4-CAR50_3 \n increase by month')

for i in range(0,4):
    axs[i].invert_yaxis()
    axs[i].grid()
    axs[i].set_ylabel('depth, m')

plt.tight_layout()
#axs[1].legend(loc = 'best', fontsize = 10)
# Out:
# 0.1931340144230944
# 4.57758976862965
# 7.171859349959732
# 8.986218574719487
# 10.386515299479015
# 10.859262319711661
# 11.343465169270985
# 11.529046474358893
# 12.482359274839837
# 13.566903921273934
# 14.47618376903074
# 15.643244816706556

# %%
# reload(ebmBOX)

# #(start, end, ftype, sdir, varname, fname, y, x)
# pkldir = '/ocean/tjarniko/MEOPAR/analysis_tereza/notebooks/PI_CARBON_PAPER/MAIN_ANALYSIS/pkls/'
# start = '2015-01-01' #start of timeperiod
# end = '2015-12-31' #end of timeperiod (typically a year)
# ftype = 'carp' #type of model result .nc 
# sdir = 'MAIN/BR_3rd_2015/' #where under directory tree do we find nps 
# varname = 'dissolved_inorganic_carbon' #name of variable


# fname = pkldir + 'BR3_DIC_means_ps2_BOX'
# y = ps2_y; x = ps2_x
# ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
# fname = pkldir + 'BR3_DIC_means_ps_BOX'
# y = ps_y; x = ps_x
# ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )

# %%
# reload(ebmBOX)

# #(start, end, ftype, sdir, varname, fname, y, x)
# pkldir = '/ocean/tjarniko/MEOPAR/analysis_tereza/notebooks/PI_CARBON_PAPER/MAIN_ANALYSIS/pkls/'
# start = '2015-01-01' #start of timeperiod
# end = '2015-12-31' #end of timeperiod (typically a year)
# ftype = 'carp' #type of model result .nc 
# sdir = 'PI9/' #where under directory tree do we find ncs 
# varname = 'dissolved_inorganic_carbon' #name of variable


# fname = pkldir + 'PI9_DIC_means_cs2_BOX'
# y = cs2_y; x = cs2_x
# ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
# fname = pkldir + 'PI9_DIC_means_cs_BOX'
# y = cs_y; x = cs_x
# ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
# fname = pkldir + 'PI9_DIC_means_cs3_BOX'
# y = cs3_y; x = cs3_x
# ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
# fname = pkldir + 'PI9_DIC_means_haro2_BOX'
# y = haro2_y; x = haro2_x
# ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
# fname = pkldir + 'PI9_DIC_means_haro_BOX'
# y = haro_y; x = haro_x
# ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
# fname = pkldir + 'PI9_DIC_means_haro3_BOX'
# y = haro3_y; x = haro3_x
# ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
# fname = pkldir + 'PI9_DIC_means_jdf2_BOX'
# y = jdf2_y; x = jdf2_x
# ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
# fname = pkldir + 'PI9_DIC_means_jdf_BOX'
# y = jdf_y; x = jdf_x
# ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
# fname = pkldir + 'PI9_DIC_means_jdf3_BOX'
# y = jdf3_y; x = jdf3_x
# ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
# fname = pkldir + 'PI9_DIC_means_ns2_BOX'
# y = ns2_y; x = ns2_x
# ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
# fname = pkldir + 'PI9_DIC_means_ns_BOX'
# y = ns_y; x = ns_x
# ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )
# fname = pkldir + 'PI9_DIC_means_ns3_BOX'
# y = ns3_y; x = ns3_x
# ebmBOX.extractor(start, end, ftype, sdir, varname, fname, y, x )

# #constant
# start = '2015-01-01' #start of timeperiod
# end = '2015-12-31' #end of timeperiod (typically a year)
# inletmask = False #are we masking out Toba/Bute/Jervis?
# sdir = '/PI9' #where under directory tree do we find ncs 

# #changes
# shortdesc = 'PI9_DIC'
# ftype = 'carp' #type of model result .nc 
# varname = 'dissolved_inorganic_carbon' #name of variable
# fname = '/ocean/tjarniko/MEOPAR/analysis_tereza/notebooks/PI_CARBON_PAPER/MAIN_ANALYSIS/pkls/' +shortdesc + '_means_inletsIN' #name of resulting pkl 
# ebm.extractor(start, end, ftype, sdir, varname, fname,  inletmask)

# %%
csize = pickle.load(open('../pkls/cellsize_alg2.pkl', 'rb')) 
print(np.shape(csize))
layervol = np.zeros(40)

for i in range(0,40):
    layervol[i] = np.nansum(csize[i,:,:])
    
#print(layervol)
totalvol = np.nansum(layervol)

umolLmean = np.nansum((diff_mmolm3*layervol)/totalvol)
print(umolLmean)
umolkgmean = np.nansum((diff_umolkg*layervol)/totalvol)
print(umolkgmean)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-bd2b77918fe4> in <module>
# ----> 1 csize = pickle.load(open('../pkls/cellsize_alg2.pkl', 'rb'))
#       2 print(np.shape(csize))
#       3 layervol = np.zeros(40)
#       4
#       5 for i in range(0,40):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../pkls/cellsize_alg2.pkl'

# %%
print('diff_umol_kg')
print(diff_umolkg)
print('diff_mmolm3')
print(diff_mmolm3)
print('diff_mmolm3-diff_umolkg')
print(diff_mmolm3-diff_umolkg)

# %%
# #where to store
# start = '2015-01-01'
# end = '2015-12-31'
# daily_means = np.zeros((40,365))
# ncfile_ar = []
# start_run = arrow.get(start)
# end_run = arrow.get(end)
# arrow_array = []
# for r in arrow.Arrow.span_range('day', start_run, end_run):
#     arrow_array.append(r)
# #no of days in array
# dayslen = len(arrow_array)

# for i in range(0,dayslen):
#     tdate = arrow_array[i][0]
#     ddmmmyy = tdate.format('DDMMMYY').lower()
#     ymd = tdate.format('YYYYMMDD')
#     pklfile = './pkls/umolkg/PI_DIC_umolkg_' + ymd +'.pkl'
#     ncfile_ar.append(pklfile)
#     if i%50 == 0:
#         print(i)

# print('done making nclen')

# for i in range(0,dayslen):

#     if (i%20 ==0):
#         print(ncfile_ar[i])

# t_test = ncfile_ar[20]
# print(t_test)
# t_test = pickle.load(open(t_test, 'rb'))
